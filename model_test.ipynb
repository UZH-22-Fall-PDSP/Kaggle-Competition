# %% [markdown]
# # 0. Dependancy

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/!_2022_fall/PDSP/kaggle/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/!_2022_fall/PDSP/kaggle

# %% [markdown]
# ### import package

# %%
import re
import requests
from bs4 import BeautifulSoup

import pandas as pd
from scipy.spatial import distance
from gensim.models import FastText
from textblob import TextBlob

from keras.preprocessing.text import Tokenizer
import re
import nltk
from string import punctuation 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import WordPunctTokenizer

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
en_stop = set(nltk.corpus.stopwords.words('english'))
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# # 1. load dataset & model

# %%
# read recipe csv file
df_recipe = pd.read_csv("./data/recipes_test.csv")
df_emissions = pd.read_csv("./data/emissions.csv")

# %%
loaded_model = FastText.load('./model/fooddotcom_model')
print(loaded_model)
# Out:
# FastText(vocab=12232, size=100, alpha=0.025)

# %% [markdown]
# # 2. data preparation

# %% [markdown]
# ### build word-vector of ingredients in DB

# %%
# list of unique ingredient name in db (total 441)
ing_db_words = df_emissions['ingredient'].unique()

# list of word-vector of ingredient name in db (total 441)
ing_db_vecs = []
for ing in ing_db_words:
    ing_db_vecs.append(loaded_model.wv.get_vector(ing))

# %% [markdown]
# ### scrapping clean data

# %%
def generate_query(name,id):
    name = name.split(" ")
    name = '-'.join(name)
    query = name + "-" + str(id)
    return query

def requestRecipeUrl(input:str):
    print(input)
    # request by url 'https://www.food.com/recipe/' + name + id
    url = 'https://www.food.com/recipe/' + input 
    r = requests.get(url)
    # get a correct url and scale to create full url
    html_doc = r.text
    soup = BeautifulSoup(html_doc, features="html.parser")
    serves = soup.find(class_="value svelte-1o10zxc").string
    print(serves)
    if len(serves) > 0 :
      if "/" in serves:
        serves = serves.split("/")
        serves = serves[0]+"%"+"2F"+serves[1]
        # 1%2F10
    print(serves)
    url_metric = r.url + '?units=metric&scale='+serves
    print(url_metric)
    # create html soup object to scrap 
    r = requests.get(url_metric)   
    html_doc = r.text
    soup = BeautifulSoup(html_doc, features="html.parser")

    return soup

# %%
def text_postprocessing(word):

  # remove special characters
  word = re.sub(r'\W', ' ', str(word))
  # remove numbers 
  word = re.sub('[0-9]+', '', word)
  # remove single characters
  word = re.sub(r'\s+[a-zA-Z]\s+', ' ', word)
  word = re.sub(r'\^[a-zA-Z]\s+', ' ', word)
  # substituting multiple spaces with single space
  word = re.sub(r'\s+', ' ', word, flags=re.I)
  # converting to lowercase
  word = word.lower()
  # remove stop words 
  tokens = word.split()
  clean = [token for token in tokens if len(token) > 2 if not token in en_stop]
  word = " ".join(clean)
  print(word)
  # leave only noun 
  word = TextBlob(word)
  pos = word.tags
  print(pos)
  word = [p[0] for p in pos if p[1] == 'NN' or p[1] == 'NNS']
  print(word)
  word = " ".join(word)
  print(word)

  return word

# %%
def parseRecipeName(soup:BeautifulSoup):
    # # INPUT(Constructor | BeautifulSoup) : BeautifulSoup constructor of Recipe URL html
    # # OUTPUT(tuple | string, List of dictionary) : Recipe Name
    recipeTitle = soup.title.text.split(' - Food.com')[0]
    return recipeTitle

def parseRecipeIngrd(soup:BeautifulSoup):
    # # INPUT(Constructor | BeautifulSoup) : BeautifulSoup constructor of Recipe URL html
    # # OUTPUT(List of dictionary) : Ingredients List
    ingrdList = findIngrd(soup)
    return ingrdList

def findIngrd(soup:BeautifulSoup):
    # # INPUT(Constructor | BeautifulSoup) : BeautifulSoup constructor of Recipe URL html
    # # OUTPUT(List of dictionary) : Ingredient Information List
    # #                              {'ingredient' : string, 'quantity' : float, 'unit' : string}

    ingrdList = []

    ultag = soup.find('ul', {'class': re.compile('^ingredient-list')})
    i = 0
    for litag in ultag.find_all('li'):
        # print(f"{i+1}/{len(ultag.find_all('li'))}")
        quant_obj = litag.find('span', {'class': re.compile('quantity')})
        ingrd_obj = litag.find('span', {'class': re.compile('text')})

        # CHECK : the item of list is the information of an ingredient.   
        if (quant_obj != None) and (ingrd_obj != None):
            print(quant_obj.text)
            if "/" in quant_obj.text:
              q_str = quant_obj.text.split("/")
              q = float(q_str [0])/float(q_str [1])
            elif "⁄" in quant_obj.text:
              q_str = quant_obj.text.split("⁄")
              q = float(q_str [0])/float(q_str [1])
            elif "-" in quant_obj.text:
              q_str = quant_obj.text.split("-")
              q = (float(q_str [0])+float(q_str [1]))/2
            elif quant_obj.text == '':
              q = 0
            else : 
              q = float(quant_obj.text)
            
            # ASSUME : If there is no unit, the unit as 'ea'
            _u = ingrd_obj.text.split()[0]
            u = _u if (_u =='ml' or _u =='g') else 'ea'

            # CHECK : the ingredient has a url for a detail.
            ingrdPage = ingrd_obj.find('a')
            if (ingrdPage != None):
                sub_url = ingrdPage['href']
                # CHECK : the ingrdient url is a Ingredient Detail page
                if ('about' in sub_url):
                    sub_url ='https://www.food.com' + sub_url
                    sub_r = requests.get(sub_url)
                    sub_html_doc = sub_r.text
                    sub_soup = BeautifulSoup(sub_html_doc, features="html.parser")
                    ingrd = sub_soup.find('h1').text

                    ingrdList.append({'ingredient' : ingrd.lower(), 'quantity' : q, 'unit' : u})
                else:
                    True
                    # TODO [CORNER CASE] Recursive Call of Scraping Recipe Page. Skip now.
            else:
                # TODO [CORNER CASE] case for the ingredient doesn't have a url link
                ingrd = ingrd_obj.text
                print(ingrd)
                ingrd = text_postprocessing(ingrd)
                ingrdList.append({'ingredient' : ingrd, 'quantity' : q, 'unit' : u})
                True
        else:
            True
        i+=1

    return ingrdList

# %% [markdown]
# # 3. find similar words

# %%
def replace_sim_words(input):
    for i, ing_org in enumerate(input):
        print("===="*10)
        print("Find most similar words of <<",ing_org['ingredient'],">> in DB")
        distances = []
        ing_org_vec = loaded_model.wv.get_vector(ing_org['ingredient'])   

        for ing_db_vec in ing_db_vecs:
            cos_sim= distance.cosine(ing_org_vec, ing_db_vec)
            distances.append(cos_sim)

        min_dis = min(distances)
        sim_word = ing_db_words[distances.index(min_dis)]
        print("found! We will repace it to <<",sim_word,">> !  similarity is", min_dis)

        if min_dis > 0.1 :
          print("but it looks not so similar :( we will mark as none from the recipe")
          input[i]['ingredient']= "none"
        else:
          input[i]['ingredient']= sim_word
        
    return input

# %% [markdown]
# # 4. Compute CO2 emission

# %%
def compute_emission(input):
    n = len(input)
    recipes = input.copy()
    for i in range(n):
      if input[i]['ingredient'] == 'none':
        recipes.remove(input[i])
    emission = 0
    for recipe in recipes:
      emission += recipe['quantity']*(df_emissions.loc[df_emissions['ingredient'] == recipe['ingredient'], 'emissions'].iloc[0])
    return emission

# %% [markdown]
# # 5. test file run

# %%
recipe_names = df_recipe['name']
recipe_ids = df_recipe['id']
emissions = []

for name,id in zip(recipe_names,recipe_ids):
    query = generate_query(name,id)
    soup = requestRecipeUrl(query)
    recipe = findIngrd(soup)
    recipe_new = replace_sim_words(recipe)
    emission = compute_emission(recipe_new)
    emissions.append(emission)
# Out:
# pretty-freaking-awesome--pulled-pork--crock-pot-484624
# 6
# 6
# https://www.food.com/recipe/pretty-freaking-awesome-pulled-pork-crock-pot-484624?units=metric&scale=6
# 1360.77-1814.36
#
#   g    pork butt
#
# pork butt
# [('pork', 'NN'), ('butt', 'NN')]
# ['pork', 'butt']
# pork butt
# 2
# 236.59
# 453.59
# 14.79
# 14.79
# 14.79
# 14.79
# 4.92
# 4.92
# 1.23
# ========================================
# Find most similar words of << pork butt >> in DB
# found! We will repace it to << pork >> !  similarity is 0.14629054069519043
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 0
# ========================================
# Find most similar words of << ginger ale >> in DB
# found! We will repace it to << ginger >> !  similarity is 0.09138751029968262
# ========================================
# Find most similar words of << barbecue sauce >> in DB
# found! We will repace it to << bbq sauce >> !  similarity is 0.1862044334411621
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !  similarity is 0
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 0
# ========================================
# Find most similar words of << paprika >> in DB
# found! We will repace it to << paprika >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0
# ========================================
# Find most similar words of << mustard, seed and powder >> in DB
# found! We will repace it to << mustard seeds >> !  similarity is 0.08241391181945801
# ========================================
# Find most similar words of << cayenne pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0.1013680100440979
# but it looks not so similar :( we will mark as none from the recipe
# acadia-s-eggplant-parmesan-399771
# 6
# 6
# https://www.food.com/recipe/acadias-eggplant-parmesan-399771?units=metric&scale=6
#
# 29.58
# 1
# 226.79
#
#   g    marinara sauce
#
# marinara sauce
# [('marinara', 'NN'), ('sauce', 'NN')]
# ['marinara', 'sauce']
# marinara sauce
# 226.79
# 14.79
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << eggplant >> in DB
# found! We will repace it to << eggplant >> !  similarity is 0
# ========================================
# Find most similar words of << marinara sauce >> in DB
# found! We will repace it to << bbq sauce >> !  similarity is 0.24531567096710205
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << mozzarella >> in DB
# found! We will repace it to << mozzarella >> !  similarity is 0
# ========================================
# Find most similar words of << parmesan cheese >> in DB
# found! We will repace it to << parmesan >> !  similarity is 0.04896080493927002
# african-chicken-curry-455721
# 4
# 4
# https://www.food.com/recipe/african-chicken-curry-455721?units=metric&scale=4
# 14.79
# 1
# 2
# 1
# 411.06
# 9.85
# 0.61
# 907.18-1360.77
# 396.89
# 1
# ========================================
# Find most similar words of << olive oil >> in DB
# found! We will repace it to << olive oil >> !  similarity is 0
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 0
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 0
# ========================================
# Find most similar words of << bay leaf >> in DB
# found! We will repace it to << bay leaves >> !  similarity is 0.18205463886260986
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << tomato >> in DB
# found! We will repace it to << tomato >> !  similarity is 0
# ========================================
# Find most similar words of << curry powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.1400715708732605
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << chicken >> in DB
# found! We will repace it to << chicken >> !  similarity is 0
# ========================================
# Find most similar words of << coconut milk or cream >> in DB
# found! We will repace it to << coconut milk >> !  similarity is 0.08769834041595459
# ========================================
# Find most similar words of << lemon >> in DB
# found! We will repace it to << lemon >> !  similarity is 0
# african-mint-chutney-454994
# 8
# 8
# https://www.food.com/recipe/african-mint-chutney-454994?units=metric&scale=8
# 118.29
# 3
# 1
#
#       chili
#
# chili
# [('chili', 'NN')]
# ['chili']
# chili
# 118.29
# 9.85
#
#   ml    coriander seeds
#
# coriander seeds
# [('coriander', 'NN'), ('seeds', 'NNS')]
# ['coriander', 'seeds']
# coriander seeds
# 14.79
# 29.58-59.16
# 236.59
#
#
# ========================================
# Find most similar words of << peanut >> in DB
# found! We will repace it to << peanut butter >> !  similarity is 0.1450420618057251
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 0
# ========================================
# Find most similar words of << chili >> in DB
# found! We will repace it to << chili >> !  similarity is 0
# ========================================
# Find most similar words of << mint >> in DB
# found! We will repace it to << mint >> !  similarity is 0
# ========================================
# Find most similar words of << coriander seeds >> in DB
# found! We will repace it to << cumin >> !  similarity is 0.1766921877861023
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << vinegar >> in DB
# found! We will repace it to << balsamic vinegar >> !  similarity is 0.08596271276473999
# ========================================
# Find most similar words of << lime >> in DB
# found! We will repace it to << lime >> !  similarity is 0
# ========================================
# Find most similar words of << yogurt >> in DB
# found! We will repace it to << yogurt >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0
# alyssa-s-favorite-fish-361646
# 4-6
# 4-6
# https://www.food.com/recipe/alyssas-favorite-fish-361646?units=metric&scale=4-6
# 354.88
#
#   ml    salt-free seasoned dried breadcrumbs (4C's is best)
#
# salt free seasoned dried breadcrumbs best
# [('salt', 'NN'), ('free', 'JJ'), ('seasoned', 'VBD'), ('dried', 'JJ'), ('breadcrumbs', 'NN'), ('best', 'JJS')]
# ['salt', 'breadcrumbs']
# salt breadcrumbs
# 118.29
# 1
#
#       lemon, juice of
#
# lemon juice
# [('lemon', 'NN'), ('juice', 'NN')]
# ['lemon', 'juice']
# lemon juice
# 4.92
# 4-6
#
#   piece    scrod fillets (you can use other white fish of your choice)
#
# piece scrod fillets use white fish choice
# [('piece', 'NN'), ('scrod', 'NN'), ('fillets', 'NNS'), ('use', 'VBP'), ('white', 'JJ'), ('fish', 'NN'), ('choice', 'NN')]
# ['piece', 'scrod', 'fillets', 'fish', 'choice']
# piece scrod fillets fish choice
#
#
#   Pam cooking spray
#
# pam cooking spray
# [('pam', 'NN'), ('cooking', 'NN'), ('spray', 'NN')]
# ['pam', 'cooking', 'spray']
# pam cooking spray
# ========================================
# Find most similar words of << salt breadcrumbs >> in DB
# found! We will repace it to << panko >> !  similarity is 0.2033979296684265
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !  similarity is 0
# ========================================
# Find most similar words of << chives >> in DB
# found! We will repace it to << chives >> !  similarity is 0
# ========================================
# Find most similar words of << piece scrod fillets fish choice >> in DB
# found! We will repace it to << sole >> !  similarity is 0.23314440250396729
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << pam cooking spray >> in DB
# found! We will repace it to << sprat >> !  similarity is 0.32671523094177246
# but it looks not so similar :( we will mark as none from the recipe
# another-mint-chutney-26219
# 1/2
# 1%2F2
# https://www.food.com/recipe/another-mint-chutney-26219?units=metric&scale=1%2F2
# 125
# 3
# 3
# 4
# 2
# 1⁄2
# ========================================
# Find most similar words of << mint >> in DB
# found! We will repace it to << mint >> !  similarity is 0
# ========================================
# Find most similar words of << chile pepper >> in DB
# found! We will repace it to << red bell pepper >> !  similarity is 0.1270596981048584
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << green onion >> in DB
# found! We will repace it to << green onion >> !  similarity is 0
# ========================================
# Find most similar words of << vinegar >> in DB
# found! We will repace it to << balsamic vinegar >> !  similarity is 0.08596271276473999
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# apple-cheese-muffins-53252
# 18
# 18
# https://www.food.com/recipe/apple-cheese-muffins-53252?units=metric&scale=18
# 118.29
# 118.29
# 2
# 354.88
# 4.92
# 2.46
# 177.44
# 158.51
# 59.14
# 236.59
# 118.29
#
#   ml    nuts
#
# nuts
# [('nuts', 'NNS')]
# ['nuts']
# nuts
# ========================================
# Find most similar words of << margarine >> in DB
# found! We will repace it to << full-fat margarine >> !  similarity is 0.041673481464385986
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 0
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 0
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.2082313895225525
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << baking soda >> in DB
# found! We will repace it to << baking soda >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << oatmeal >> in DB
# found! We will repace it to << oats >> !  similarity is 0.13029319047927856
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !  similarity is 0
# ========================================
# Find most similar words of << milk >> in DB
# found! We will repace it to << milk >> !  similarity is 0
# ========================================
# Find most similar words of << apple >> in DB
# found! We will repace it to << apple >> !  similarity is 0
# ========================================
# Find most similar words of << nuts >> in DB
# found! We will repace it to << walnuts >> !  similarity is 0.08139795064926147
# asparagus-in-creamy-orange-maltaise-butter-sauce-186382
# 6
# 6
# https://www.food.com/recipe/asparagus-in-creamy-orange-maltaise-butter-sauce-186382?units=metric&scale=6
# 450
# 3
#
#       egg yolks
#
# egg yolks
# [('egg', 'NN'), ('yolks', 'NNS')]
# ['egg', 'yolks']
# egg yolks
# 1
#
#
# 100
# 14.79
# 44.37
#
#
#   orange rind twists (garnish)
#
# orange rind twists garnish
# [('orange', 'NN'), ('rind', 'NN'), ('twists', 'NNS'), ('garnish', 'VBP')]
# ['orange', 'rind', 'twists']
# orange rind twists
# ========================================
# Find most similar words of << asparagus >> in DB
# found! We will repace it to << green asparagus >> !  similarity is 0.0393180251121521
# ========================================
# Find most similar words of << egg yolks >> in DB
# found! We will repace it to << egg >> !  similarity is 0.2623438239097595
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << orange >> in DB
# found! We will repace it to << orange >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !  similarity is 0
# ========================================
# Find most similar words of << heavy cream >> in DB
# found! We will repace it to << whipping cream >> !  similarity is 0.20997601747512817
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << orange rind twists >> in DB
# found! We will repace it to << orange peel >> !  similarity is 0.13480299711227417
# but it looks not so similar :( we will mark as none from the recipe
# aunty-diane-s-yummy-burgers-130632
# 6
# 6
# https://www.food.com/recipe/aunty-dianes-yummy-burgers-130632?units=metric&scale=6
# 453.59
# 453.59
# 78.78
# 4.92
# 118.29
#
#
#   salt & pepper
#
# salt pepper
# [('salt', 'NN'), ('pepper', 'NN')]
# ['salt', 'pepper']
# salt pepper
# 1
# 59.14
# ========================================
# Find most similar words of << beef >> in DB
# found! We will repace it to << beef >> !  similarity is 0
# ========================================
# Find most similar words of << pork >> in DB
# found! We will repace it to << pork >> !  similarity is 0
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 0
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.1286921501159668
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << oatmeal >> in DB
# found! We will repace it to << oats >> !  similarity is 0.13029319047927856
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << salt pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0.08345168828964233
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 0
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !  similarity is 0.18924224376678467
# but it looks not so similar :( we will mark as none from the recipe
# autumn-tea-257067
# 3
# 3
# https://www.food.com/recipe/autumn-tea-257067?units=metric&scale=3
# 5
# 1182.95
# 1182.95
#
#   ml    apple juice, unsweetened
#
# apple juice unsweetened
# [('apple', 'NN'), ('juice', 'NN'), ('unsweetened', 'VBD')]
# ['apple', 'juice']
# apple juice
# 473.18
# 118.29
# 78.78
# 1.23
# ========================================
# Find most similar words of << tea >> in DB
# found! We will repace it to << tea >> !  similarity is 0
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !  similarity is 0.18924224376678467
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << apple juice >> in DB
# found! We will repace it to << apple juice >> !  similarity is 0
# ========================================
# Find most similar words of << cranberry >> in DB
# found! We will repace it to << apricot >> !  similarity is 0.26592177152633667
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 0
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !  similarity is 0
# ========================================
# Find most similar words of << pumpkin pie spice >> in DB
# found! We will repace it to << pumpkin >> !  similarity is 0.09399032592773438
# avocado-sandwiches-28149
# 4
# 4
# https://www.food.com/recipe/avocado-sandwiches-28149?units=metric&scale=4
# 453.59
# 2
#
#
#   salt and pepper, to taste
#
# salt pepper taste
# [('salt', 'NN'), ('pepper', 'IN'), ('taste', 'NN')]
# ['salt', 'taste']
# salt taste
# 78.78
# 14.79
# 8
#
#   slice    whole wheat bread, toasted
#
# slice whole wheat bread toasted
# [('slice', 'NN'), ('whole', 'JJ'), ('wheat', 'NN'), ('bread', 'NN'), ('toasted', 'VBD')]
# ['slice', 'wheat', 'bread']
# slice wheat bread
# ========================================
# Find most similar words of << bacon >> in DB
# found! We will repace it to << bacon >> !  similarity is 0
# ========================================
# Find most similar words of << avocado >> in DB
# found! We will repace it to << avocado >> !  similarity is 0
# ========================================
# Find most similar words of << salt taste >> in DB
# found! We will repace it to << tabasco sauce >> !  similarity is 0.2873045802116394
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << mayonnaise >> in DB
# found! We will repace it to << mayonnaise >> !  similarity is 0
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !  similarity is 0
# ========================================
# Find most similar words of << slice wheat bread >> in DB
# found! We will repace it to << wheat bread >> !  similarity is 0.16771262884140015
# but it looks not so similar :( we will mark as none from the recipe
# banana-buttermilk-pancakes-112082
# 6
# 6
# https://www.food.com/recipe/banana-buttermilk-pancakes-112082?units=metric&scale=6
# 118.29
# 118.29
# 44.37
# 2.46
# 1.23
# 1.23
# 236.59
# 1
# 22.18
# 9.85
# 1
#
#
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.2082313895225525
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.2082313895225525
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !  similarity is 0
# ========================================
# Find most similar words of << baking powder >> in DB
# found! We will repace it to << baking powder >> !  similarity is 0
# ========================================
# Find most similar words of << baking soda >> in DB
# found! We will repace it to << baking soda >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << buttermilk >> in DB
# found! We will repace it to << buttermilk >> !  similarity is 0
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 0
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << canola oil >> in DB
# found! We will repace it to << sesame oil >> !  similarity is 0.3299194574356079
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << banana >> in DB
# found! We will repace it to << banana >> !  similarity is 0
# ========================================
# Find most similar words of << maple syrup >> in DB
# found! We will repace it to << agave syrup >> !  similarity is 0.14338791370391846
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << walnut >> in DB
# found! We will repace it to << walnuts >> !  similarity is 0.384848415851593
# but it looks not so similar :( we will mark as none from the recipe
# barbecue-chicken-and-rice-154088
# 6
# 6
# https://www.food.com/recipe/barbecue-chicken-and-rice-154088?units=metric&scale=6
# 1133.98
# 29.58
# 295.73
# 177.44
# 354.88
# 236.59
# ========================================
# Find most similar words of << chicken >> in DB
# found! We will repace it to << chicken >> !  similarity is 0
# ========================================
# Find most similar words of << olive oil >> in DB
# found! We will repace it to << olive oil >> !  similarity is 0
# ========================================
# Find most similar words of << barbecue sauce >> in DB
# found! We will repace it to << bbq sauce >> !  similarity is 0.1862044334411621
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !  similarity is 0.18924224376678467
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << rice >> in DB
# found! We will repace it to << rice >> !  similarity is 0
# ========================================
# Find most similar words of << corn >> in DB
# found! We will repace it to << corn >> !  similarity is 0
# bbq-sauce-great-for-chicken-wings-313094
# 4
# 4
# https://www.food.com/recipe/bbq-sauce-great-for-chicken-wings-313094?units=metric&scale=4
# 118.29
# 118.29
# 118.29
# 78.78
# 78.78
# 78.78
# 2.46
# 29.58
# 2.46
# 2.46
# 4.92
# ========================================
# Find most similar words of << cider vinegar >> in DB
# found! We will repace it to << apple vinegar >> !  similarity is 0.08320295810699463
# ========================================
# Find most similar words of << worcestershire sauce >> in DB
# found! We will repace it to << tabasco sauce >> !  similarity is 0.12844783067703247
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << ketchup >> in DB
# found! We will repace it to << ketchup >> !  similarity is 0
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !  similarity is 0
# ========================================
# Find most similar words of << molasses >> in DB
# found! We will repace it to << honey >> !  similarity is 0.2821892499923706
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 0
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.1286921501159668
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << chili powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.12026137113571167
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0
# ========================================
# Find most similar words of << celery seed >> in DB
# found! We will repace it to << celery >> !  similarity is 0.09856170415878296
# beans-and-rice-and-corn-382812
# 4
# 4
# https://www.food.com/recipe/beans-and-rice-and-corn-382812?units=metric&scale=4
# 59.14
# 59.14
# 3
# 236.59
# 591.47
# 425.24
# 446.50
#
#
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 0
# ========================================
# Find most similar words of << green onion >> in DB
# found! We will repace it to << green onion >> !  similarity is 0
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 0
# ========================================
# Find most similar words of << rice >> in DB
# found! We will repace it to << rice >> !  similarity is 0
# ========================================
# Find most similar words of << broth >> in DB
# found! We will repace it to << beef broth >> !  similarity is 0.10510295629501343
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << black bean >> in DB
# found! We will repace it to << black beans >> !  similarity is 0.08820098638534546
# ========================================
# Find most similar words of << corn >> in DB
# found! We will repace it to << corn >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0
# becky-s-apple-crisp-64322
# 1
# 1
# https://www.food.com/recipe/beckys-apple-crisp-64322?units=metric&scale=1
# 6-8
# 1.23
# 118.29
# 118.29
# 118.29
# 118.29
# 118.29
#
# ========================================
# Find most similar words of << apple >> in DB
# found! We will repace it to << apple >> !  similarity is 0
# ========================================
# Find most similar words of << cinnamon >> in DB
# found! We will repace it to << cinnamon >> !  similarity is 0
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 0
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !  similarity is 0
# ========================================
# Find most similar words of << oatmeal >> in DB
# found! We will repace it to << oats >> !  similarity is 0.13029319047927856
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.2082313895225525
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << ice cream >> in DB
# found! We will repace it to << sour cream >> !  similarity is 0.16081476211547852
# but it looks not so similar :( we will mark as none from the recipe
# beef-chili-n-cheddar-potatoes-10328
# 4
# 4
# https://www.food.com/recipe/beef-chilin-cheddar-potatoes-10328?units=metric&scale=4
# 680.38
# 4
# 14.79
# 425.24
# 354.88
# 59.14
# 2.46
# ========================================
# Find most similar words of << beef >> in DB
# found! We will repace it to << beef >> !  similarity is 0
# ========================================
# Find most similar words of << potato >> in DB
# found! We will repace it to << potato >> !  similarity is 0
# ========================================
# Find most similar words of << chili powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.12026137113571167
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << pink bean >> in DB
# found! We will repace it to << soybean oil >> !  similarity is 0.3239762783050537
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !  similarity is 0
# ========================================
# Find most similar words of << green onion >> in DB
# found! We will repace it to << green onion >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# beer-brine-274736
# 1
# 1
# https://www.food.com/recipe/beer-brine-274736?units=metric&scale=1
# 14.79
# 2
# 2-3
# 6
# 709.77
# 118.29
# 59.14
# 340.19
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0
# ========================================
# Find most similar words of << thyme >> in DB
# found! We will repace it to << thyme >> !  similarity is 0
# ========================================
# Find most similar words of << bay leaf >> in DB
# found! We will repace it to << bay leaves >> !  similarity is 0.18205463886260986
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 0
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !  similarity is 0.18924224376678467
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !  similarity is 0
# ========================================
# Find most similar words of << beer >> in DB
# found! We will repace it to << beer >> !  similarity is 0
# bombay-sweet-potatoes-424780
# 6
# 6
# https://www.food.com/recipe/bombay-sweet-potatoes-424780?units=metric&scale=6
# 453.59
# 14.79
#
#   ml    vegetable oil
#
# vegetable oil
# [('vegetable', 'JJ'), ('oil', 'NN')]
# ['oil']
# oil
# 4.92
# 1
# 14.79
# 1
# 2.46
# 4.92
# 4.92
# 4.92
# 2.46
# 2
# 14.79
# ========================================
# Find most similar words of << sweet potato >> in DB
# found! We will repace it to << sweet potato >> !  similarity is 0
# ========================================
# Find most similar words of << oil >> in DB
# found! We will repace it to << olive oil >> !  similarity is 0.32794928550720215
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << mustard, seed and powder >> in DB
# found! We will repace it to << mustard seeds >> !  similarity is 0.08241391181945801
# ========================================
# Find most similar words of << bay leaf >> in DB
# found! We will repace it to << bay leaves >> !  similarity is 0.18205463886260986
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << ginger >> in DB
# found! We will repace it to << ginger >> !  similarity is 0
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 0
# ========================================
# Find most similar words of << turmeric >> in DB
# found! We will repace it to << turmeric >> !  similarity is 0
# ========================================
# Find most similar words of << chili powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.12026137113571167
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !  similarity is 0
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << tomato >> in DB
# found! We will repace it to << tomato >> !  similarity is 0
# ========================================
# Find most similar words of << cilantro >> in DB
# found! We will repace it to << cilantro >> !  similarity is 0
# broccoli-potato-soup-with-greens-390247
# 4
# 4
# https://www.food.com/recipe/broccoli-potato-soup-with-greens-390247?units=metric&scale=4
# 2
#
#   medium    red potatoes, chopped
#
# medium red potatoes chopped
# [('medium', 'NN'), ('red', 'VBD'), ('potatoes', 'NNS'), ('chopped', 'VBD')]
# ['medium', 'potatoes']
# medium potatoes
# 396.89
# 709.77
# 473.18
# 44.37
# 473.18
# 473.18
#
# ========================================
# Find most similar words of << medium potatoes >> in DB
# found! We will repace it to << russet  potato >> !  similarity is 0.2857701778411865
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << broth >> in DB
# found! We will repace it to << beef broth >> !  similarity is 0.10510295629501343
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << broccoli >> in DB
# found! We will repace it to << broccoli >> !  similarity is 0
# ========================================
# Find most similar words of << milk >> in DB
# found! We will repace it to << milk >> !  similarity is 0
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.2082313895225525
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << gouda >> in DB
# found! We will repace it to << cheddar cheese >> !  similarity is 0.2129763960838318
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << greens >> in DB
# found! We will repace it to << arugula >> !  similarity is 0.20295172929763794
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << gouda >> in DB
# found! We will repace it to << cheddar cheese >> !  similarity is 0.2129763960838318
# but it looks not so similar :( we will mark as none from the recipe
# butter-meltaways-with-lemon-frosting-513985
# 3
# 3
# https://www.food.com/recipe/butter-meltaways-with-lemon-frosting-513985?units=metric&scale=3
# 236.59
# 78.78
# 295.73
# 177.44
# 59.14
# 354.88
# 22.18-29.58
# 14.79
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << powdered sugar >> in DB
# found! We will repace it to << icing sugar >> !  similarity is 0.11064720153808594
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.2082313895225525
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << cornstarch >> in DB
# found! We will repace it to << cornstarch >> !  similarity is 0
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << powdered sugar >> in DB
# found! We will repace it to << icing sugar >> !  similarity is 0.11064720153808594
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !  similarity is 0
# ========================================
# Find most similar words of << lemon >> in DB
# found! We will repace it to << lemon >> !  similarity is 0
# cajun-crescent-turnovers-206463
# 8
# 8
# https://www.food.com/recipe/cajun-crescent-turnovers-206463?units=metric&scale=8
# 118.29
# 59.14
# 59.14
# 14.79
# 29.58
# 177.44
# 473.18
# 473.18
# 14.79
# 9.85
#
#   ml    hot pepper sauce
#
# hot pepper sauce
# [('hot', 'JJ'), ('pepper', 'NN'), ('sauce', 'NN')]
# ['pepper', 'sauce']
# pepper sauce
# 2.46
# 2.46
# 2.46
#
#   ml    creole seasoning
#
# creole seasoning
# [('creole', 'NN'), ('seasoning', 'VBG')]
# ['creole']
# creole
# 453.59
#
#   g    crescent rolls
#
# crescent rolls
# [('crescent', 'NN'), ('rolls', 'NNS')]
# ['crescent', 'rolls']
# crescent rolls
# 1
# 2.46
# 0.61
#
#   ml    garlic salt
#
# garlic salt
# [('garlic', 'JJ'), ('salt', 'NN')]
# ['salt']
# salt
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 0
# ========================================
# Find most similar words of << sweet pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0.1891462206840515
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << celery >> in DB
# found! We will repace it to << celery >> !  similarity is 0
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 0
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << mushroom >> in DB
# found! We will repace it to << portobello mushrooms >> !  similarity is 0.18630081415176392
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << wild rice >> in DB
# found! We will repace it to << wild rice >> !  similarity is 0
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !  similarity is 0.18924224376678467
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << worcestershire sauce >> in DB
# found! We will repace it to << tabasco sauce >> !  similarity is 0.12844783067703247
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << pepper sauce >> in DB
# found! We will repace it to << red bell pepper >> !  similarity is 0.14902609586715698
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.1286921501159668
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << cayenne pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0.1013680100440979
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << creole >> in DB
# found! We will repace it to << red bell pepper >> !  similarity is 0.31556153297424316
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << crescent rolls >> in DB
# found! We will repace it to << rape oil >> !  similarity is 0.5545739233493805
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 0
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.1286921501159668
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# chamorro-cucumber-slices-38596
# 4
# 4
# https://www.food.com/recipe/chamorro-cucumber-slices-38596?units=metric&scale=4
# 2-3
# 59.14
# 0.61
# 59.14
# 2
# 29.57
# ========================================
# Find most similar words of << cucumber >> in DB
# found! We will repace it to << cucumber >> !  similarity is 0
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 0
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0
# ========================================
# Find most similar words of << soy sauce >> in DB
# found! We will repace it to << soy sauce >> !  similarity is 0
# ========================================
# Find most similar words of << vinegar >> in DB
# found! We will repace it to << balsamic vinegar >> !  similarity is 0.08596271276473999
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !  similarity is 0.18924224376678467
# but it looks not so similar :( we will mark as none from the recipe
# cheesy-sausage-balls-23706
# 3
# 3
# https://www.food.com/recipe/cheesy-sausage-balls-23706?units=metric&scale=3
# 453.59
# 177.44
# 226.79
# 59.14
# 59.14
# 2.46
# 2.46
# ========================================
# Find most similar words of << sausage >> in DB
# found! We will repace it to << sausage >> !  similarity is 0
# ========================================
# Find most similar words of << biscuit mix >> in DB
# found! We will repace it to << puff pastry >> !  similarity is 0.5319977700710297
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !  similarity is 0
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 0
# ========================================
# Find most similar words of << celery >> in DB
# found! We will repace it to << celery >> !  similarity is 0
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.1286921501159668
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0
# cheremsha--siberian-onion-salad-292213
# 4
# 4
# https://www.food.com/recipe/cheremsha-siberian-onion-salad-292213?units=metric&scale=4
# 255.14
# 3
#
#       hardboiled egg
#
# hardboiled egg
# [('hardboiled', 'VBN'), ('egg', 'NN')]
# ['egg']
# egg
# 44.37
# 29.58
#
#
# ========================================
# Find most similar words of << green onion >> in DB
# found! We will repace it to << green onion >> !  similarity is 0
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 0
# ========================================
# Find most similar words of << sour cream >> in DB
# found! We will repace it to << sour cream >> !  similarity is 0
# ========================================
# Find most similar words of << mayonnaise >> in DB
# found! We will repace it to << mayonnaise >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0
# chicken--bacon-and-white-bean-soup-portuguese-style-370726
# 8-12
# 8-12
# https://www.food.com/recipe/chicken-bacon-and-white-bean-soup-portuguese-style-370726?units=metric&scale=8-12
# 453.59
# 226.79
# 473.18
# 118.29
# 29.58
# 14.79
# 2
# 4.92
# 1.23
# 1892.0
#
#   ml    chicken stock
#
# chicken stock
# [('chicken', 'NN'), ('stock', 'NN')]
# ['chicken', 'stock']
# chicken stock
# 340.19
#
#   g    cooked chicken, diced
#
# cooked chicken diced
# [('cooked', 'VBN'), ('chicken', 'NN'), ('diced', 'VBD')]
# ['chicken']
# chicken
# 236.59
# ========================================
# Find most similar words of << white bean >> in DB
# found! We will repace it to << white wine >> !  similarity is 0.16837656497955322
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << bacon >> in DB
# found! We will repace it to << bacon >> !  similarity is 0
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 0
# ========================================
# Find most similar words of << celery >> in DB
# found! We will repace it to << celery >> !  similarity is 0
# ========================================
# Find most similar words of << shallot >> in DB
# found! We will repace it to << shallot >> !  similarity is 0
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 0
# ========================================
# Find most similar words of << bay leaf >> in DB
# found! We will repace it to << bay leaves >> !  similarity is 0.18205463886260986
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << cayenne pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0.1013680100440979
# ...
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 0
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !  similarity is 0.18924224376678467
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << package chocolate chips >> in DB
# found! We will repace it to << dark chocolate >> !  similarity is 0.19275057315826416
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << vanilla >> in DB
# found! We will repace it to << vanilla >> !  similarity is 0
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 0
# ========================================
# Find most similar words of << nuts >> in DB
# found! We will repace it to << walnuts >> !  similarity is 0.08139795064926147
# no-guilt-pumpkin-cookies-169079
# 60
# 60
# https://www.food.com/recipe/no-guilt-pumpkin-cookies-169079?units=metric&scale=60
# 118.29
# 118.29
# 236.59
# 236.59
# 4.92
# 1
# 473.18
# 59.14
# 4.92
# 4.92
# 4.92
# 1.23
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 0
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !  similarity is 0
# ========================================
# Find most similar words of << margarine >> in DB
# found! We will repace it to << full-fat margarine >> !  similarity is 0.041673481464385986
# ========================================
# Find most similar words of << pumpkin >> in DB
# found! We will repace it to << pumpkin >> !  similarity is 0
# ========================================
# Find most similar words of << vanilla >> in DB
# found! We will repace it to << vanilla >> !  similarity is 0
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 0
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.2082313895225525
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << flax seed >> in DB
# found! We will repace it to << poppy seed >> !  similarity is 0.16131490468978882
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << baking powder >> in DB
# found! We will repace it to << baking powder >> !  similarity is 0
# ========================================
# Find most similar words of << baking soda >> in DB
# found! We will repace it to << baking soda >> !  similarity is 0
# ========================================
# Find most similar words of << cinnamon >> in DB
# found! We will repace it to << cinnamon >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# oatmeal-raisin-applesauce-cookies-150554
# 24
# 24
# https://www.food.com/recipe/oatmeal-raisin-applesauce-cookies-150554?units=metric&scale=24
# 236.59
# 4.92
# 2.46
# 2.46
# 29.58
# 118.29
# 118.29
# 59.14
# 1
# 4.92
# 315.37
# 118.29
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.2082313895225525
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << baking powder >> in DB
# found! We will repace it to << baking powder >> !  similarity is 0
# ========================================
# Find most similar words of << baking soda >> in DB
# found! We will repace it to << baking soda >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 0
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !  similarity is 0
# ========================================
# Find most similar words of << applesauce >> in DB
# found! We will repace it to << apple vinegar >> !  similarity is 0.3328664302825928
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 0
# ========================================
# Find most similar words of << vanilla >> in DB
# found! We will repace it to << vanilla >> !  similarity is 0
# ========================================
# Find most similar words of << oatmeal >> in DB
# found! We will repace it to << oats >> !  similarity is 0.13029319047927856
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << raisin >> in DB
# found! We will repace it to << dates >> !  similarity is 0.3552427291870117
# but it looks not so similar :( we will mark as none from the recipe
# original--nilla-banana-pudding-37000
# 1
# 1
# https://www.food.com/recipe/original-nilla-banana-pudding-37000?units=metric&scale=1
# 177.44
# 78.78
# 0.25
# 3
# 473.18
# 2.46
# 45
#
#       vanilla wafers, divided
#
# vanilla wafers divided
# [('vanilla', 'NN'), ('wafers', 'NNS'), ('divided', 'VBD')]
# ['vanilla', 'wafers']
# vanilla wafers
# 5
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 0
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.2082313895225525
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 0
# ========================================
# Find most similar words of << milk >> in DB
# found! We will repace it to << milk >> !  similarity is 0
# ========================================
# Find most similar words of << vanilla >> in DB
# found! We will repace it to << vanilla >> !  similarity is 0
# ========================================
# Find most similar words of << vanilla wafers >> in DB
# found! We will repace it to << vanilla >> !  similarity is 0.13998806476593018
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << banana >> in DB
# found! We will repace it to << banana >> !  similarity is 0
# potato-and-red--pepper-frittata-91195
# 4
# 4
# https://www.food.com/recipe/potato-and-red-pepper-frittata-91195?units=metric&scale=4
# 14.78
# 1
# 1
# 2
# 8
# 2.46
# 0.61
# ========================================
# Find most similar words of << olive oil >> in DB
# found! We will repace it to << olive oil >> !  similarity is 0
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 0
# ========================================
# Find most similar words of << sweet pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0.1891462206840515
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << potato >> in DB
# found! We will repace it to << potato >> !  similarity is 0
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0
# sole-francese-76402
# 4
# 4
# https://www.food.com/recipe/sole-francese-76402?units=metric&scale=4
# 453.59
#
#   g    sole (dover sole is nice...real thin)
#
# sole dover sole nice real thin
# [('sole', 'JJ'), ('dover', 'NN'), ('sole', 'JJ'), ('nice', 'JJ'), ('real', 'JJ'), ('thin', 'NN')]
# ['dover', 'thin']
# dover thin
# 118.29
# 3
# 88.74
# 2.46
# 29.58
# 29.58
# 1
# 118.29
# 1
# 14.79
# ========================================
# Find most similar words of << dover thin >> in DB
# found! We will repace it to << jabuticabas >> !  similarity is 0.4370906949043274
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.2082313895225525
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 0
# ========================================
# Find most similar words of << parmesan cheese >> in DB
# found! We will repace it to << parmesan >> !  similarity is 0.04896080493927002
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# ========================================
# Find most similar words of << olive oil >> in DB
# found! We will repace it to << olive oil >> !  similarity is 0
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << lemon >> in DB
# found! We will repace it to << lemon >> !  similarity is 0
# ========================================
# Find most similar words of << marsala >> in DB
# found! We will repace it to << wine >> !  similarity is 0.24823182821273804
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 0
# ========================================
# Find most similar words of << cornstarch >> in DB
# found! We will repace it to << cornstarch >> !  similarity is 0
# soy-ginger-flank-steak-with-garlic-210236
# 6-8
# 6-8
# https://www.food.com/recipe/soy-ginger-flank-steak-with-garlic-210236?units=metric&scale=6-8
# 78.78
# 78.78
# 14.79
# 14.79
# 453.59-907.18
#
#   g    flank steak
#
# flank steak
# [('flank', 'NN'), ('steak', 'NN')]
# ['flank', 'steak']
# flank steak
# ========================================
# Find most similar words of << soy sauce >> in DB
# found! We will repace it to << soy sauce >> !  similarity is 0
# ========================================
# Find most similar words of << honey >> in DB
# found! We will repace it to << honey >> !  similarity is 0
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 0
# ========================================
# Find most similar words of << ginger >> in DB
# found! We will repace it to << ginger >> !  similarity is 0
# ========================================
# Find most similar words of << flank steak >> in DB
# found! We will repace it to << swordfish >> !  similarity is 0.25624144077301025
# but it looks not so similar :( we will mark as none from the recipe
# sparkling-paradise-229351
# 1
# 1
# https://www.food.com/recipe/sparkling-paradise-229351?units=metric&scale=1
# 85.04
#
#   g   paradise mango rum liqueur
#
# paradise mango rum liqueur
# [('paradise', 'NN'), ('mango', 'NN'), ('rum', 'NN'), ('liqueur', 'NN')]
# ['paradise', 'mango', 'rum', 'liqueur']
# paradise mango rum liqueur
# 85.04
#
#   g    lemon-lime flavored soda (or club soda for less sweet taste)
#
# lemon lime flavored soda club soda less sweet taste
# [('lemon', 'JJ'), ('lime', 'NN'), ('flavored', 'VBD'), ('soda', 'NN'), ('club', 'NN'), ('soda', 'NN'), ('less', 'JJR'), ('sweet', 'JJ'), ('taste', 'NN')]
# ['lime', 'soda', 'club', 'soda', 'taste']
# lime soda club soda taste
# ========================================
# Find most similar words of << paradise mango rum liqueur >> in DB
# found! We will repace it to << langostino >> !  similarity is 0.22816205024719238
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << lime soda club soda taste >> in DB
# found! We will repace it to << lemon juice >> !  similarity is 0.2694518566131592
# but it looks not so similar :( we will mark as none from the recipe
# the-simplest-tomato-sauce-ever---marcella-hazan-273976
# 4
# 4
# https://www.food.com/recipe/the-simplest-tomato-sauce-ever-marcella-hazan-273976?units=metric&scale=4
# 473.18
# 73.94
# 1
#
# ========================================
# Find most similar words of << plum tomato >> in DB
# found! We will repace it to << tomato >> !  similarity is 0.08631742000579834
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 0
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 0
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 0
# tuna--pea--and-brown-rice-casserole-97966
# 5
# 5
# https://www.food.com/recipe/tuna-pea-and-brown-rice-casserole-97966?units=metric&scale=5
# 236.59
# 304.75
#
#   g can  campbell condensed golden mushroom soup
#
# campbell condensed golden mushroom soup
# [('campbell', 'NN'), ('condensed', 'VBD'), ('golden', 'JJ'), ('mushroom', 'NN'), ('soup', 'NN')]
# ['campbell', 'mushroom', 'soup']
# campbell mushroom soup
# 170.09
# 236.59
#
#   ml    frozen peas, cooked and drained
#
# frozen peas cooked drained
# [('frozen', 'JJ'), ('peas', 'NNS'), ('cooked', 'VBD'), ('drained', 'JJ')]
# ['peas']
# peas
#
# 29.58
#
#   ml    dry breadcrumbs
#
# dry breadcrumbs
# [('dry', 'JJ'), ('breadcrumbs', 'NN')]
# ['breadcrumbs']
# breadcrumbs
# 118.29
# ========================================
# Find most similar words of << brown rice >> in DB
# found! We will repace it to << brown rice >> !  similarity is 0
# ========================================
# Find most similar words of << campbell mushroom soup >> in DB
# found! We will repace it to << morel mushrooms >> !  similarity is 0.23757541179656982
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << tuna >> in DB
# found! We will repace it to << tuna >> !  similarity is 0
# ========================================
# Find most similar words of << peas >> in DB
# found! We will repace it to << peas >> !  similarity is 0
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0
# ========================================
# Find most similar words of << breadcrumbs >> in DB
# found! We will repace it to << panko >> !  similarity is 0.1749514937400818
# but it looks not so similar :( we will mark as none from the recipe
# ========================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !  similarity is 0

# %% [markdown]
# #6. export test result to csv

# %%
emission_series = pd.Series(emissions)/1000
frame = { 'Id': recipe_ids, 'Predicted': emission_series}
result = pd.DataFrame(frame)
#Printing elements of Dataframe
print(result)
result.to_csv('./result/result10.csv', index=False)  # threshold 0.2
# Out:
#         Id  Predicted
# 0   484624   0.430138
# 1   399771   1.333170
# 2   455721   3.842630
# 3   454994   0.610500
# 4   361646   1.005724
# 5    26219   0.059421
# 6    53252   3.024486
# 7   186382   1.372856
# 8   130632  10.519877
# 9   257067   0.598148
# 10   28149   1.623842
# 11  112082   1.106923
# 12  154088   3.765148
# 13  313094   0.899948
# 14  382812   1.278242
# 15   64322   1.149287
# 16   10328  15.545166
# 17  274736   0.454920
# 18  424780   0.248795
# 19  390247   1.313074
# 20  513985   2.692046
# 21  206463   1.117212
# 22   38596   0.120678
# 23   23706   5.151267
# 24  292213   0.309960
# 25  370726   4.733672
# 26  240843   8.642292
# 27   49249   0.557817
# 28  110813   0.041742
# 29   66190   4.542498
# 30  252674  14.339432
# 31  512810   0.091080
# 32  113725   2.341371
# 33   41874   7.674466
# 34   61210   0.255851
# 35   41725   4.564554
# 36  177958   1.429016
# 37   53907   0.103609
# 38  137627   0.224852
# 39  485002   0.908696
# 40   19441   0.954266
# 41  169079   0.697364
# 42  150554   0.472167
# 43   37000   1.078887
# 44   91195   0.067330
# 45   76402   0.922851
# 46  210236   0.281911
# 47  229351   0.000000
# 48  273976   1.513046
# 49   97966   2.970060
