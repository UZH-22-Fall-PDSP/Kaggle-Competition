# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/!_2022_fall/PDSP/kaggle/
# Out:
# /content/gdrive/MyDrive/!_2022_fall/PDSP/kaggle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Prepare dataset

# %%
# read recipe csv file
df_train = pd.read_csv("RAW_recipes.csv")

# %%
df_train.shape
# Out:
# (231637, 12)

# %%
steps = df_train['steps']
reviews = df_train['description']
ingredients = df_train['ingredients']

# %% [markdown]
# ### normalization & tokenizing

# %%
from keras.preprocessing.text import Tokenizer
import re
import nltk
from string import punctuation 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import WordPunctTokenizer

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
en_stop = set(nltk.corpus.stopwords.words('english'))

# %%
tokenizer = nltk.WordPunctTokenizer()

def preprocessing(document):
  # remove special characters
  document = re.sub(r'\W', ' ', str(document))

  # remove numbers 
  document = re.sub('[0-9]+', '', document)

  # remove single characters
  document = re.sub(r'\s+[a-zA-Z]\s+', ' ', document)
  document = re.sub(r'\^[a-zA-Z]\s+', ' ', document)

  # substituting multiple spaces with single space
  document = re.sub(r'\s+', ' ', document, flags=re.I)

  # converting to lowercase
  dodument = document.lower()

  # tokenizing 
  document = tokenizer.tokenize(document) 

  # remove stop words 
  document = [w for w in document if len(w) > 2 if not w in en_stop]
  '''
  # lemmatization 
  tokens = document.split()
  stemmer = WordNetLemmatizer()
  tokens = [stemmer.lemmatize(word) for word in tokens]
  tokens = [word for word in tokens if word not in en_stop]
  tokens = [word for word in tokens if len(word)>3]

  res = ' '.join(tokens)
  '''

  return document

# %%
# preprocessing dataset 
preprocessed_steps = [preprocessing(sentence) for sentence in steps if sentence.strip() != '']

# %%
preprocessed_steps[0]

# %% [markdown]
# ## Training fastText

# %% [markdown]
# learn more about the gensim fastText model parameter : https://radimrehurek.com/gensim/models/fasttext.html
#
# quick tutorial : https://github.com/PacktPublishing/fastText-Quick-Start-Guide/blob/master/chapter5/fasttext%20with%20gensim.ipynb

# %%
from gensim.models import FastText

# %%
model = FastText(preprocessed_steps, size=100, window=5, min_count=5, workers=4,sg=1)

# %%
model.wv.most_similar("macadamia nut")
# Out:
# [('macadamia', 0.9698609113693237),
#  ('macadamias', 0.9531890153884888),
#  ('walnuts', 0.734894871711731),
#  ('cashew', 0.7241073846817017),
#  ('almonds', 0.7235787510871887),
#  ('nuts', 0.7228017449378967),
#  ('pistachio', 0.7166469097137451),
#  ('pistachios', 0.7151767015457153),
#  ('pecans', 0.6972396969795227),
#  ('cashewnuts', 0.6871625781059265)]

# %%
model.wv.most_similar("riccota cheese")
# Out:
# [('riccota', 0.8869120478630066),
#  ('cheese', 0.8205503821372986),
#  ('ricotta', 0.7524741888046265),
#  ('cheeses', 0.7492947578430176),
#  ('asiago', 0.7462842464447021),
#  ('mozzeralla', 0.7407122850418091),
#  ('creamcheese', 0.7369866371154785),
#  ('cottage', 0.7360917925834656),
#  ('mozza', 0.7321102023124695),
#  ('chees', 0.7266157865524292)]

# %% [markdown]
# ## save model

# %%
model.save('fooddotcom_model')

# %%
loaded_model = FastText.load('fooddotcom_model')
print(loaded_model)
# Out:
# FastText(vocab=12232, size=100, alpha=0.025)

# %% [markdown]
# # Test

# %%
import re
import requests
from bs4 import BeautifulSoup

# %%
def generate_query(name,id):
    name = name.split(" ")
    name = '-'.join(name)
    query = name + "-" + str(id)
    return query

# %%
def requestRecipeUrl(input:str):
    print(input)
    # request by url 'https://www.food.com/recipe/' + name + id
    url = 'https://www.food.com/recipe/' + input 
    r = requests.get(url)
    # get a correct url and scale to create full url
    html_doc = r.text
    soup = BeautifulSoup(html_doc, features="html.parser")
    serves = soup.find(class_="value svelte-1o10zxc").string
    if len(serves) > 0 :
      serves.split("-")
      serves = serves[0]
    url_metric = r.url + '?units=metric&scale='+serves
    print(url_metric)
    # create html soup object to scrap 
    r = requests.get(url_metric)   
    html_doc = r.text
    soup = BeautifulSoup(html_doc, features="html.parser")

    return soup

# %%
input = 'alyssa-s-favorite-fish-361646'

# %%
res = requestRecipeUrl(input)
# Out:
# alyssa-s-favorite-fish-361646
# https://www.food.com/recipe/alyssas-favorite-fish-361646?units=metric&scale=4

# %%
def parseRecipeName(soup:BeautifulSoup):
    # # INPUT(Constructor | BeautifulSoup) : BeautifulSoup constructor of Recipe URL html
    # # OUTPUT(tuple | string, List of dictionary) : Recipe Name
    recipeTitle = soup.title.text.split(' - Food.com')[0]
    return recipeTitle

def parseRecipeIngrd(soup:BeautifulSoup):
    # # INPUT(Constructor | BeautifulSoup) : BeautifulSoup constructor of Recipe URL html
    # # OUTPUT(List of dictionary) : Ingredients List
    ingrdList = findIngrd(soup)
    return ingrdList

def findIngrd(soup:BeautifulSoup):
    # # INPUT(Constructor | BeautifulSoup) : BeautifulSoup constructor of Recipe URL html
    # # OUTPUT(List of dictionary) : Ingredient Information List
    # #                              {'ingredient' : string, 'quantity' : float, 'unit' : string}

    ingrdList = []

    ultag = soup.find('ul', {'class': re.compile('^ingredient-list')})
    i = 0
    for litag in ultag.find_all('li'):
        # print(f"{i+1}/{len(ultag.find_all('li'))}")
        quant_obj = litag.find('span', {'class': re.compile('quantity')})
        ingrd_obj = litag.find('span', {'class': re.compile('text')})

        # CHECK : the item of list is the information of an ingredient.
        if (quant_obj != None) and (ingrd_obj != None):
            q_str = quant_obj.text.split('-')
            q_str = q_str[0] # [CornerCase] e.g. 10-13
            q = float(q_str)/10 if q_str != '' else float(0) # scale down from 10 to 1

            # ASSUME : If there is no unit, the unit as 'ea'
            _u = ingrd_obj.text.split()[0]
            u = _u if (_u =='ml' or _u =='g') else 'ea'

            # CHECK : the ingredient has a url for a detail.
            ingrdPage = ingrd_obj.find('a')
            if (ingrdPage != None):
                sub_url = ingrdPage['href']
                # CHECK : the ingrdient url is a Ingredient Detail page
                if ('about' in sub_url):
                    sub_url ='https://www.food.com' + sub_url
                    sub_r = requests.get(sub_url)
                    sub_html_doc = sub_r.text
                    sub_soup = BeautifulSoup(sub_html_doc, features="html.parser")
                    ingrd = sub_soup.find('h1').text

                    ingrdList.append({'ingredient' : ingrd.lower(), 'quantity' : q, 'unit' : u})
                else:
                    True
                    # TODO [CORNER CASE] Recursive Call of Scraping Recipe Page. Skip now.
            else:
                # TODO [CORNER CASE] case for the ingredient doesn't have a url link
                True
        else:
            True
        i+=1

    return ingrdList

# %%
name = 'pretty freaking awesome  pulled pork crock pot'
id = 484624

query = generate_query(name,id)
soup = requestRecipeUrl(query)
recipe = findIngrd(soup)

print(recipe)
# Out:
# pretty-freaking-awesome--pulled-pork-crock-pot-484624
# https://www.food.com/recipe/pretty-freaking-awesome-pulled-pork-crock-pot-484624?units=metric&scale=6
# [{'ingredient': 'onion', 'quantity': 0.2, 'unit': 'ea'}, {'ingredient': 'ginger ale', 'quantity': 23.659, 'unit': 'ml'}, {'ingredient': 'barbecue sauce', 'quantity': 45.358999999999995, 'unit': 'g'}, {'ingredient': 'brown sugar', 'quantity': 1.4789999999999999, 'unit': 'ml'}, {'ingredient': 'sugar', 'quantity': 1.4789999999999999, 'unit': 'ml'}, {'ingredient': 'paprika', 'quantity': 1.4789999999999999, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 1.4789999999999999, 'unit': 'ml'}, {'ingredient': 'pepper', 'quantity': 0.492, 'unit': 'ml'}, {'ingredient': 'mustard, seed and powder', 'quantity': 0.492, 'unit': 'ml'}, {'ingredient': 'cayenne pepper', 'quantity': 0.123, 'unit': 'ml'}]

# %% [markdown]
# ### load test file

# %%
# read recipe csv file
df_recipe = pd.read_csv("recipes_test.csv")
df_emissions = pd.read_csv("emissions.csv")

# %% [markdown]
# ### compute word vectors

# %%
# list of unique ingredient name in db (total 441)
ing_db_words = df_emissions['ingredient'].unique()

# %%
# list of word-vector of ingredient name in db (total 441)
ing_db_vecs = []
for ing in ing_db_words:
    ing_db_vecs.append(loaded_model.wv.get_vector(ing))

# %% [markdown]
# ### compute com sim

# %%
from scipy.spatial import distance

# %%
def replace_sim_words(input):
    for i, ing_org in enumerate(input):
        print("===="*10)
        print("Find most similar words of <<",ing_org['ingredient'],">> in DB")
        distances = []
        ing_org_vec = loaded_model.wv.get_vector(ing_org['ingredient'])   

        for ing_db_vec in ing_db_vecs:
            cos_sim= distance.cosine(ing_org_vec, ing_db_vec)
            distances.append(cos_sim)

        min_dis = min(distances)
        sim_word = ing_db_words[distances.index(min_dis)]
        print("found! We will repace it to <<",sim_word,">> !")
        input[i]['ingredient']= sim_word
        
    return input

# %%
replace_sim_words(recipe)
# Out:
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << ginger ale >> in DB
# found! We will repace it to << ginger >> !
# ========================================
# Find most similar words of << barbecue sauce >> in DB
# found! We will repace it to << bbq sauce >> !
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << paprika >> in DB
# found! We will repace it to << paprika >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << mustard, seed and powder >> in DB
# found! We will repace it to << mustard seeds >> !
# ========================================
# Find most similar words of << cayenne pepper >> in DB
# found! We will repace it to << pepper >> !
# [{'ingredient': 'onion', 'quantity': 0.2, 'unit': 'ea'},
#  {'ingredient': 'ginger', 'quantity': 23.659, 'unit': 'ml'},
#  {'ingredient': 'bbq sauce', 'quantity': 45.358999999999995, 'unit': 'g'},
#  {'ingredient': 'brown sugar', 'quantity': 1.4789999999999999, 'unit': 'ml'},
#  {'ingredient': 'sugar', 'quantity': 1.4789999999999999, 'unit': 'ml'},
#  {'ingredient': 'paprika', 'quantity': 1.4789999999999999, 'unit': 'ml'},
#  {'ingredient': 'salt', 'quantity': 1.4789999999999999, 'unit': 'ml'},
#  {'ingredient': 'pepper', 'quantity': 0.492, 'unit': 'ml'},
#  {'ingredient': 'mustard seeds', 'quantity': 0.492, 'unit': 'ml'},
#  {'ingredient': 'pepper', 'quantity': 0.123, 'unit': 'ml'}]

# %% [markdown]
# ### compute emission

# %%
def compute_emission(input):
    emission = 0
    for recipe in input:
        emission += recipe['quantity']*(df_emissions.loc[df_emissions['ingredient'] == recipe['ingredient'], 'emissions'].iloc[0])
    return emission

# %%
compute_emission(recipe)
# Out:
# 88.2553417

# %% [markdown]
# ### Test file run and save as csv

# %%
recipe_names = df_recipe['name']
recipe_ids = df_recipe['id']
emissions = []

for name,id in zip(recipe_names,recipe_ids):
    query = generate_query(name,id)
    soup = requestRecipeUrl(query)
    recipe = findIngrd(soup)
    recipe_new = replace_sim_words(recipe)
    emission = compute_emission(recipe_new)
    emissions.append(emission)
# Out:
# pretty-freaking-awesome--pulled-pork--crock-pot-484624
# https://www.food.com/recipe/pretty-freaking-awesome-pulled-pork-crock-pot-484624?units=metric&scale=6
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << ginger ale >> in DB
# found! We will repace it to << ginger >> !
# ========================================
# Find most similar words of << barbecue sauce >> in DB
# found! We will repace it to << bbq sauce >> !
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << paprika >> in DB
# found! We will repace it to << paprika >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << mustard, seed and powder >> in DB
# found! We will repace it to << mustard seeds >> !
# ========================================
# Find most similar words of << cayenne pepper >> in DB
# found! We will repace it to << pepper >> !
# acadia-s-eggplant-parmesan-399771
# https://www.food.com/recipe/acadias-eggplant-parmesan-399771?units=metric&scale=6
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << eggplant >> in DB
# found! We will repace it to << eggplant >> !
# ========================================
# Find most similar words of << mozzarella >> in DB
# found! We will repace it to << mozzarella >> !
# ========================================
# Find most similar words of << parmesan cheese >> in DB
# found! We will repace it to << parmesan >> !
# african-chicken-curry-455721
# https://www.food.com/recipe/african-chicken-curry-455721?units=metric&scale=4
# ========================================
# Find most similar words of << olive oil >> in DB
# found! We will repace it to << olive oil >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << bay leaf >> in DB
# found! We will repace it to << bay leaves >> !
# ========================================
# Find most similar words of << tomato >> in DB
# found! We will repace it to << tomato >> !
# ========================================
# Find most similar words of << curry powder >> in DB
# found! We will repace it to << onion powder >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << chicken >> in DB
# found! We will repace it to << chicken >> !
# ========================================
# Find most similar words of << coconut milk or cream >> in DB
# found! We will repace it to << coconut milk >> !
# ========================================
# Find most similar words of << lemon >> in DB
# found! We will repace it to << lemon >> !
# african-mint-chutney-454994
# https://www.food.com/recipe/african-mint-chutney-454994?units=metric&scale=8
# ========================================
# Find most similar words of << peanut >> in DB
# found! We will repace it to << peanut butter >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << mint >> in DB
# found! We will repace it to << mint >> !
# ========================================
# Find most similar words of << vinegar >> in DB
# found! We will repace it to << balsamic vinegar >> !
# ========================================
# Find most similar words of << lime >> in DB
# found! We will repace it to << lime >> !
# ========================================
# Find most similar words of << yogurt >> in DB
# found! We will repace it to << yogurt >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# alyssa-s-favorite-fish-361646
# https://www.food.com/recipe/alyssas-favorite-fish-361646?units=metric&scale=4
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << chives >> in DB
# found! We will repace it to << chives >> !
# another-mint-chutney-26219
# https://www.food.com/recipe/another-mint-chutney-26219?units=metric&scale=1
# ========================================
# Find most similar words of << mint >> in DB
# found! We will repace it to << mint >> !
# ========================================
# Find most similar words of << chile pepper >> in DB
# found! We will repace it to << red bell pepper >> !
# ========================================
# Find most similar words of << green onion >> in DB
# found! We will repace it to << green onion >> !
# ========================================
# Find most similar words of << vinegar >> in DB
# found! We will repace it to << balsamic vinegar >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# apple-cheese-muffins-53252
# https://www.food.com/recipe/apple-cheese-muffins-53252?units=metric&scale=1
# ========================================
# Find most similar words of << margarine >> in DB
# found! We will repace it to << full-fat margarine >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << baking soda >> in DB
# found! We will repace it to << baking soda >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << oatmeal >> in DB
# found! We will repace it to << oats >> !
# ========================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !
# ========================================
# Find most similar words of << milk >> in DB
# found! We will repace it to << milk >> !
# ========================================
# Find most similar words of << apple >> in DB
# found! We will repace it to << apple >> !
# asparagus-in-creamy-orange-maltaise-butter-sauce-186382
# https://www.food.com/recipe/asparagus-in-creamy-orange-maltaise-butter-sauce-186382?units=metric&scale=6
# ========================================
# Find most similar words of << asparagus >> in DB
# found! We will repace it to << green asparagus >> !
# ========================================
# Find most similar words of << orange >> in DB
# found! We will repace it to << orange >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !
# ========================================
# Find most similar words of << heavy cream >> in DB
# found! We will repace it to << whipping cream >> !
# aunty-diane-s-yummy-burgers-130632
# https://www.food.com/recipe/aunty-dianes-yummy-burgers-130632?units=metric&scale=6
# ========================================
# Find most similar words of << beef >> in DB
# found! We will repace it to << beef >> !
# ========================================
# Find most similar words of << pork >> in DB
# found! We will repace it to << pork >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !
# ========================================
# Find most similar words of << oatmeal >> in DB
# found! We will repace it to << oats >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !
# autumn-tea-257067
# https://www.food.com/recipe/autumn-tea-257067?units=metric&scale=3
# ========================================
# Find most similar words of << tea >> in DB
# found! We will repace it to << tea >> !
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !
# ========================================
# Find most similar words of << cranberry >> in DB
# found! We will repace it to << apricot >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !
# ========================================
# Find most similar words of << pumpkin pie spice >> in DB
# found! We will repace it to << pumpkin >> !
# avocado-sandwiches-28149
# https://www.food.com/recipe/avocado-sandwiches-28149?units=metric&scale=4
# ========================================
# Find most similar words of << bacon >> in DB
# found! We will repace it to << bacon >> !
# ========================================
# Find most similar words of << avocado >> in DB
# found! We will repace it to << avocado >> !
# ========================================
# Find most similar words of << mayonnaise >> in DB
# found! We will repace it to << mayonnaise >> !
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !
# banana-buttermilk-pancakes-112082
# https://www.food.com/recipe/banana-buttermilk-pancakes-112082?units=metric&scale=6
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !
# ========================================
# Find most similar words of << baking powder >> in DB
# found! We will repace it to << baking powder >> !
# ========================================
# Find most similar words of << baking soda >> in DB
# found! We will repace it to << baking soda >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << buttermilk >> in DB
# found! We will repace it to << buttermilk >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << canola oil >> in DB
# found! We will repace it to << sesame oil >> !
# ========================================
# Find most similar words of << banana >> in DB
# found! We will repace it to << banana >> !
# ========================================
# Find most similar words of << maple syrup >> in DB
# found! We will repace it to << agave syrup >> !
# ========================================
# Find most similar words of << walnut >> in DB
# found! We will repace it to << walnuts >> !
# barbecue-chicken-and-rice-154088
# https://www.food.com/recipe/barbecue-chicken-and-rice-154088?units=metric&scale=6
# ========================================
# Find most similar words of << chicken >> in DB
# found! We will repace it to << chicken >> !
# ========================================
# Find most similar words of << olive oil >> in DB
# found! We will repace it to << olive oil >> !
# ========================================
# Find most similar words of << barbecue sauce >> in DB
# found! We will repace it to << bbq sauce >> !
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !
# ========================================
# Find most similar words of << rice >> in DB
# found! We will repace it to << rice >> !
# ========================================
# Find most similar words of << corn >> in DB
# found! We will repace it to << corn >> !
# bbq-sauce-great-for-chicken-wings-313094
# https://www.food.com/recipe/bbq-sauce-great-for-chicken-wings-313094?units=metric&scale=4
# ========================================
# Find most similar words of << cider vinegar >> in DB
# found! We will repace it to << apple vinegar >> !
# ========================================
# Find most similar words of << worcestershire sauce >> in DB
# found! We will repace it to << tabasco sauce >> !
# ========================================
# Find most similar words of << ketchup >> in DB
# found! We will repace it to << ketchup >> !
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !
# ========================================
# Find most similar words of << molasses >> in DB
# found! We will repace it to << honey >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << chili powder >> in DB
# found! We will repace it to << onion powder >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << celery seed >> in DB
# found! We will repace it to << celery >> !
# beans-and-rice-and-corn-382812
# https://www.food.com/recipe/beans-and-rice-and-corn-382812?units=metric&scale=4
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << green onion >> in DB
# found! We will repace it to << green onion >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << rice >> in DB
# found! We will repace it to << rice >> !
# ========================================
# Find most similar words of << broth >> in DB
# found! We will repace it to << beef broth >> !
# ========================================
# Find most similar words of << black bean >> in DB
# found! We will repace it to << black beans >> !
# ========================================
# Find most similar words of << corn >> in DB
# found! We will repace it to << corn >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# becky-s-apple-crisp-64322
# https://www.food.com/recipe/beckys-apple-crisp-64322?units=metric&scale=1
# ========================================
# Find most similar words of << apple >> in DB
# found! We will repace it to << apple >> !
# ========================================
# Find most similar words of << cinnamon >> in DB
# found! We will repace it to << cinnamon >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !
# ========================================
# Find most similar words of << oatmeal >> in DB
# found! We will repace it to << oats >> !
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << ice cream >> in DB
# found! We will repace it to << sour cream >> !
# beef-chili-n-cheddar-potatoes-10328
# https://www.food.com/recipe/beef-chilin-cheddar-potatoes-10328?units=metric&scale=4
# ========================================
# Find most similar words of << beef >> in DB
# found! We will repace it to << beef >> !
# ========================================
# Find most similar words of << potato >> in DB
# found! We will repace it to << potato >> !
# ========================================
# Find most similar words of << chili powder >> in DB
# found! We will repace it to << onion powder >> !
# ========================================
# Find most similar words of << pink bean >> in DB
# found! We will repace it to << soybean oil >> !
# ========================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !
# ========================================
# Find most similar words of << green onion >> in DB
# found! We will repace it to << green onion >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# beer-brine-274736
# https://www.food.com/recipe/beer-brine-274736?units=metric&scale=1
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << thyme >> in DB
# found! We will repace it to << thyme >> !
# ========================================
# Find most similar words of << bay leaf >> in DB
# found! We will repace it to << bay leaves >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !
# ========================================
# Find most similar words of << beer >> in DB
# found! We will repace it to << beer >> !
# bombay-sweet-potatoes-424780
# https://www.food.com/recipe/bombay-sweet-potatoes-424780?units=metric&scale=6
# ========================================
# Find most similar words of << sweet potato >> in DB
# found! We will repace it to << sweet potato >> !
# ========================================
# Find most similar words of << mustard, seed and powder >> in DB
# found! We will repace it to << mustard seeds >> !
# ========================================
# Find most similar words of << bay leaf >> in DB
# found! We will repace it to << bay leaves >> !
# ========================================
# Find most similar words of << ginger >> in DB
# found! We will repace it to << ginger >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << turmeric >> in DB
# found! We will repace it to << turmeric >> !
# ========================================
# Find most similar words of << chili powder >> in DB
# found! We will repace it to << onion powder >> !
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << tomato >> in DB
# found! We will repace it to << tomato >> !
# ========================================
# Find most similar words of << cilantro >> in DB
# found! We will repace it to << cilantro >> !
# broccoli-potato-soup-with-greens-390247
# https://www.food.com/recipe/broccoli-potato-soup-with-greens-390247?units=metric&scale=4
# ========================================
# Find most similar words of << broth >> in DB
# found! We will repace it to << beef broth >> !
# ========================================
# Find most similar words of << broccoli >> in DB
# found! We will repace it to << broccoli >> !
# ========================================
# Find most similar words of << milk >> in DB
# found! We will repace it to << milk >> !
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << gouda >> in DB
# found! We will repace it to << cheddar cheese >> !
# ========================================
# Find most similar words of << greens >> in DB
# found! We will repace it to << arugula >> !
# ========================================
# Find most similar words of << gouda >> in DB
# found! We will repace it to << cheddar cheese >> !
# butter-meltaways-with-lemon-frosting-513985
# https://www.food.com/recipe/butter-meltaways-with-lemon-frosting-513985?units=metric&scale=3
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << powdered sugar >> in DB
# found! We will repace it to << icing sugar >> !
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << cornstarch >> in DB
# found! We will repace it to << cornstarch >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << powdered sugar >> in DB
# found! We will repace it to << icing sugar >> !
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !
# ========================================
# Find most similar words of << lemon >> in DB
# found! We will repace it to << lemon >> !
# cajun-crescent-turnovers-206463
# https://www.food.com/recipe/cajun-crescent-turnovers-206463?units=metric&scale=8
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << sweet pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << celery >> in DB
# found! We will repace it to << celery >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << mushroom >> in DB
# found! We will repace it to << portobello mushrooms >> !
# ========================================
# Find most similar words of << wild rice >> in DB
# found! We will repace it to << wild rice >> !
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !
# ========================================
# Find most similar words of << worcestershire sauce >> in DB
# found! We will repace it to << tabasco sauce >> !
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !
# ========================================
# Find most similar words of << cayenne pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !
# chamorro-cucumber-slices-38596
# https://www.food.com/recipe/chamorro-cucumber-slices-38596?units=metric&scale=4
# ========================================
# Find most similar words of << cucumber >> in DB
# found! We will repace it to << cucumber >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << soy sauce >> in DB
# found! We will repace it to << soy sauce >> !
# ========================================
# Find most similar words of << vinegar >> in DB
# found! We will repace it to << balsamic vinegar >> !
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !
# cheesy-sausage-balls-23706
# https://www.food.com/recipe/cheesy-sausage-balls-23706?units=metric&scale=3
# ========================================
# Find most similar words of << sausage >> in DB
# found! We will repace it to << sausage >> !
# ========================================
# Find most similar words of << biscuit mix >> in DB
# found! We will repace it to << puff pastry >> !
# ========================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << celery >> in DB
# found! We will repace it to << celery >> !
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# cheremsha--siberian-onion-salad-292213
# https://www.food.com/recipe/cheremsha-siberian-onion-salad-292213?units=metric&scale=4
# ========================================
# Find most similar words of << green onion >> in DB
# found! We will repace it to << green onion >> !
# ========================================
# Find most similar words of << sour cream >> in DB
# found! We will repace it to << sour cream >> !
# ========================================
# Find most similar words of << mayonnaise >> in DB
# found! We will repace it to << mayonnaise >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# chicken--bacon-and-white-bean-soup-portuguese-style-370726
# https://www.food.com/recipe/chicken-bacon-and-white-bean-soup-portuguese-style-370726?units=metric&scale=8
# ========================================
# Find most similar words of << white bean >> in DB
# found! We will repace it to << white wine >> !
# ========================================
# Find most similar words of << bacon >> in DB
# found! We will repace it to << bacon >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << celery >> in DB
# found! We will repace it to << celery >> !
# ========================================
# Find most similar words of << shallot >> in DB
# found! We will repace it to << shallot >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << bay leaf >> in DB
# found! We will repace it to << bay leaves >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << cayenne pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << romano cheese >> in DB
# found! We will repace it to << cheese >> !
# chuck-wagon-potatoes-240843
# https://www.food.com/recipe/chuck-wagon-potatoes-240843?units=metric&scale=8
# ========================================
# Find most similar words of << potato >> in DB
# found! We will repace it to << potato >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << shallot >> in DB
# found! We will repace it to << shallot >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << bacon >> in DB
# found! We will repace it to << bacon >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !
# ========================================
# Find most similar words of << chives >> in DB
# found! We will repace it to << chives >> !
# corn-pudding-49249
# https://www.food.com/recipe/corn-pudding-49249?units=metric&scale=6
# ========================================
# Find most similar words of << corn >> in DB
# found! We will repace it to << corn >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << milk >> in DB
# found! We will repace it to << milk >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# cucumber-salsa-110813
# https://www.food.com/recipe/cucumber-salsa-110813?units=metric&scale=1
# ========================================
# Find most similar words of << cucumber >> in DB
# found! We will repace it to << cucumber >> !
# ========================================
# Find most similar words of << tomato >> in DB
# found! We will repace it to << tomato >> !
# ========================================
# Find most similar words of << sweet pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << lime >> in DB
# found! We will repace it to << lime >> !
# ========================================
# Find most similar words of << parsley >> in DB
# found! We will repace it to << parsley >> !
# ========================================
# Find most similar words of << cilantro >> in DB
# found! We will repace it to << cilantro >> !
# ========================================
# Find most similar words of << dill >> in DB
# found! We will repace it to << dill >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# deidre-s-extraordinary-chocolate-chip-cookies-66190
# https://www.food.com/recipe/deidres-extraordinary-chocolate-chip-cookies-66190?units=metric&scale=4
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << baking soda >> in DB
# found! We will repace it to << baking soda >> !
# ========================================
# Find most similar words of << cream of tartar >> in DB
# found! We will repace it to << whipping cream >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << milk >> in DB
# found! We will repace it to << milk >> !
# ========================================
# Find most similar words of << vanilla >> in DB
# found! We will repace it to << vanilla >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# delicious-oven-baked-beef-stew-252674
# https://www.food.com/recipe/delicious-oven-baked-beef-stew-252674?units=metric&scale=6
# ========================================
# Find most similar words of << bacon grease >> in DB
# found! We will repace it to << bacon >> !
# ========================================
# Find most similar words of << beef >> in DB
# found! We will repace it to << beef >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !
# ========================================
# Find most similar words of << tomato >> in DB
# found! We will repace it to << tomato >> !
# ========================================
# Find most similar words of << red pepper flakes >> in DB
# found! We will repace it to << red bell pepper >> !
# ========================================
# Find most similar words of << broth >> in DB
# found! We will repace it to << beef broth >> !
# ========================================
# Find most similar words of << tapioca >> in DB
# found! We will repace it to << tap water >> !
# ========================================
# Find most similar words of << bouillon >> in DB
# found! We will repace it to << beef broth >> !
# ========================================
# Find most similar words of << worcestershire sauce >> in DB
# found! We will repace it to << tabasco sauce >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << carrot >> in DB
# found! We will repace it to << carrot >> !
# ========================================
# Find most similar words of << celery >> in DB
# found! We will repace it to << celery >> !
# ========================================
# Find most similar words of << potato >> in DB
# found! We will repace it to << potato >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# dr--fuhrman-s-walnut-vinaigrette-dressing-512810
# https://www.food.com/recipe/dr-fuhrmans-walnut-vinaigrette-dressing-512810?units=metric&scale=1
# ========================================
# Find most similar words of << raisin >> in DB
# found! We will repace it to << dates >> !
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !
# ========================================
# Find most similar words of << mustard, prepared >> in DB
# found! We will repace it to << mustard >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << thyme >> in DB
# found! We will repace it to << thyme >> !
# ========================================
# Find most similar words of << walnut >> in DB
# found! We will repace it to << walnuts >> !
# easy-baking-powder-babka-113725
# https://www.food.com/recipe/easy-baking-powder-babka-113725?units=metric&scale=1
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << baking powder >> in DB
# found! We will repace it to << baking powder >> !
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << raisin >> in DB
# found! We will repace it to << dates >> !
# elbows-and-ham-bake-41874
# https://www.food.com/recipe/elbows-and-ham-bake-41874?units=metric&scale=4
# ========================================
# Find most similar words of << macaroni >> in DB
# found! We will repace it to << pasta >> !
# ========================================
# Find most similar words of << ham >> in DB
# found! We will repace it to << ham >> !
# ========================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !
# ========================================
# Find most similar words of << margarine >> in DB
# found! We will repace it to << full-fat margarine >> !
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << mustard, seed and powder >> in DB
# found! We will repace it to << mustard seeds >> !
# ========================================
# Find most similar words of << milk >> in DB
# found! We will repace it to << milk >> !
# ========================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !
# ========================================
# Find most similar words of << paprika >> in DB
# found! We will repace it to << paprika >> !
# garlic-sauteed-artichokes-61210
# https://www.food.com/recipe/garlic-sauteed-artichokes-61210?units=metric&scale=4
# ========================================
# Find most similar words of << artichoke >> in DB
# found! We will repace it to << artichoke >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !
# ========================================
# Find most similar words of << broth >> in DB
# found! We will repace it to << beef broth >> !
# grandma-s-raisin-filled-cookies-41725
# https://www.food.com/recipe/grandmas-raisin-filled-cookies-41725?units=metric&scale=3
# ========================================
# Find most similar words of << raisin >> in DB
# found! We will repace it to << dates >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << baking powder >> in DB
# found! We will repace it to << baking powder >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << milk >> in DB
# found! We will repace it to << milk >> !
# ========================================
# Find most similar words of << vanilla >> in DB
# found! We will repace it to << vanilla >> !
# grilled-zucchini-with-garlic-and-lemon-butter-baste-177958
# https://www.food.com/recipe/grilled-zucchini-with-garlic-and-lemon-butter-baste-177958?units=metric&scale=8
# ========================================
# Find most similar words of << zucchini >> in DB
# found! We will repace it to << zucchini >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !
# ========================================
# Find most similar words of << oregano >> in DB
# found! We will repace it to << oregano >> !
# ========================================
# Find most similar words of << curry powder >> in DB
# found! We will repace it to << onion powder >> !
# ========================================
# Find most similar words of << parmesan cheese >> in DB
# found! We will repace it to << parmesan >> !
# hamburger-and-kd-casserole-53907
# https://www.food.com/recipe/hamburger-and-kd-casserole-53907?units=metric&scale=4
# ========================================
# Find most similar words of << beef >> in DB
# found! We will repace it to << beef >> !
# ========================================
# Find most similar words of << pea >> in DB
# found! We will repace it to << peas >> !
# ========================================
# Find most similar words of << carrot >> in DB
# found! We will repace it to << carrot >> !
# ========================================
# Find most similar words of << sour cream >> in DB
# found! We will repace it to << sour cream >> !
# ========================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !
# lemon-chicken-just-like-take-out-137627
# https://www.food.com/recipe/lemon-chicken-just-like-take-out-137627?units=metric&scale=6
# ========================================
# Find most similar words of << chicken >> in DB
# found! We will repace it to << chicken >> !
# ========================================
# Find most similar words of << soy sauce >> in DB
# found! We will repace it to << soy sauce >> !
# ========================================
# Find most similar words of << cornstarch >> in DB
# found! We will repace it to << cornstarch >> !
# ========================================
# Find most similar words of << baking powder >> in DB
# found! We will repace it to << baking powder >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << cornstarch >> in DB
# found! We will repace it to << cornstarch >> !
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !
# ========================================
# Find most similar words of << broth >> in DB
# found! We will repace it to << beef broth >> !
# ========================================
# Find most similar words of << lemon >> in DB
# found! We will repace it to << lemon >> !
# mango-and-baby-tomato-salad-485002
# https://www.food.com/recipe/mango-and-baby-tomato-salad-485002?units=metric&scale=4
# ========================================
# Find most similar words of << flax seed >> in DB
# found! We will repace it to << poppy seed >> !
# ========================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !
# ========================================
# Find most similar words of << coriander >> in DB
# found! We will repace it to << cumin >> !
# ========================================
# Find most similar words of << mint >> in DB
# found! We will repace it to << mint >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << tomato >> in DB
# found! We will repace it to << tomato >> !
# ========================================
# Find most similar words of << mango >> in DB
# found! We will repace it to << mango >> !
# ========================================
# Find most similar words of << cilantro >> in DB
# found! We will repace it to << cilantro >> !
# nestle-toll-house-double-chocolate-brownies-19441
# https://www.food.com/recipe/nestle-toll-house-double-chocolate-brownies-19441?units=metric&scale=1
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << baking soda >> in DB
# found! We will repace it to << baking soda >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !
# ========================================
# Find most similar words of << vanilla >> in DB
# found! We will repace it to << vanilla >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# no-guilt-pumpkin-cookies-169079
# https://www.food.com/recipe/no-guilt-pumpkin-cookies-169079?units=metric&scale=6
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !
# ========================================
# Find most similar words of << margarine >> in DB
# found! We will repace it to << full-fat margarine >> !
# ========================================
# Find most similar words of << pumpkin >> in DB
# found! We will repace it to << pumpkin >> !
# ========================================
# Find most similar words of << vanilla >> in DB
# found! We will repace it to << vanilla >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << flax seed >> in DB
# found! We will repace it to << poppy seed >> !
# ========================================
# Find most similar words of << baking powder >> in DB
# found! We will repace it to << baking powder >> !
# ========================================
# Find most similar words of << baking soda >> in DB
# found! We will repace it to << baking soda >> !
# ========================================
# Find most similar words of << cinnamon >> in DB
# found! We will repace it to << cinnamon >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# oatmeal-raisin-applesauce-cookies-150554
# https://www.food.com/recipe/oatmeal-raisin-applesauce-cookies-150554?units=metric&scale=2
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << baking powder >> in DB
# found! We will repace it to << baking powder >> !
# ========================================
# Find most similar words of << baking soda >> in DB
# found! We will repace it to << baking soda >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !
# ========================================
# Find most similar words of << applesauce >> in DB
# found! We will repace it to << apple vinegar >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << vanilla >> in DB
# found! We will repace it to << vanilla >> !
# ========================================
# Find most similar words of << oatmeal >> in DB
# found! We will repace it to << oats >> !
# ========================================
# Find most similar words of << raisin >> in DB
# found! We will repace it to << dates >> !
# original--nilla-banana-pudding-37000
# https://www.food.com/recipe/original-nilla-banana-pudding-37000?units=metric&scale=1
# ========================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << milk >> in DB
# found! We will repace it to << milk >> !
# ========================================
# Find most similar words of << vanilla >> in DB
# found! We will repace it to << vanilla >> !
# ========================================
# Find most similar words of << banana >> in DB
# found! We will repace it to << banana >> !
# potato-and-red--pepper-frittata-91195
# https://www.food.com/recipe/potato-and-red-pepper-frittata-91195?units=metric&scale=4
# ========================================
# Find most similar words of << olive oil >> in DB
# found! We will repace it to << olive oil >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << sweet pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << potato >> in DB
# found! We will repace it to << potato >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# sole-francese-76402
# https://www.food.com/recipe/sole-francese-76402?units=metric&scale=4
# ========================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !
# ========================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !
# ========================================
# Find most similar words of << parmesan cheese >> in DB
# found! We will repace it to << parmesan >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# ========================================
# Find most similar words of << olive oil >> in DB
# found! We will repace it to << olive oil >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << lemon >> in DB
# found! We will repace it to << lemon >> !
# ========================================
# Find most similar words of << marsala >> in DB
# found! We will repace it to << wine >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << cornstarch >> in DB
# found! We will repace it to << cornstarch >> !
# soy-ginger-flank-steak-with-garlic-210236
# https://www.food.com/recipe/soy-ginger-flank-steak-with-garlic-210236?units=metric&scale=6
# ========================================
# Find most similar words of << soy sauce >> in DB
# found! We will repace it to << soy sauce >> !
# ========================================
# Find most similar words of << honey >> in DB
# found! We will repace it to << honey >> !
# ========================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !
# ========================================
# Find most similar words of << ginger >> in DB
# found! We will repace it to << ginger >> !
# sparkling-paradise-229351
# https://www.food.com/recipe/sparkling-paradise-229351?units=metric&scale=1
# the-simplest-tomato-sauce-ever---marcella-hazan-273976
# https://www.food.com/recipe/the-simplest-tomato-sauce-ever-marcella-hazan-273976?units=metric&scale=4
# ========================================
# Find most similar words of << plum tomato >> in DB
# found! We will repace it to << tomato >> !
# ========================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !
# ========================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !
# ========================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !
# tuna--pea--and-brown-rice-casserole-97966
# https://www.food.com/recipe/tuna-pea-and-brown-rice-casserole-97966?units=metric&scale=5
# ========================================
# Find most similar words of << brown rice >> in DB
# found! We will repace it to << brown rice >> !
# ========================================
# Find most similar words of << tuna >> in DB
# found! We will repace it to << tuna >> !
# ========================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !
# ========================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !

# %%
emission_series = pd.Series(emissions)/100
frame = { 'Id': recipe_ids, 'Predicted': emission_series}
result = pd.DataFrame(frame)
#Printing elements of Dataframe
print(result)
result.to_csv('result2.csv', index=False)
# Out:
#         Id  Predicted
# 0   484624   0.882553
# 1   399771   1.333170
# 2   455721   3.320890
# 3   454994   0.840349
# 4   361646   1.005315
# 5    26219   0.192102
# 6    53252   0.176495
# 7   186382   1.564091
# 8   130632  10.626037
# 9   257067   0.929582
# 10   28149   1.623842
# 11  112082   1.231292
# 12  154088   4.055881
# 13  313094   1.576812
# 14  382812   2.331059
# 15   64322   1.282282
# 16   10328  18.148326
# 17  274736   0.456249
# 18  424780   0.269431
# 19  390247   9.336082
# 20  513985   3.021318
# 21  206463   1.759975
# 22   38596   0.118993
# 23   23706   5.445188
# 24  292213   0.303840
# 25  370726   5.545767
# 26  240843   8.567903
# 27   49249   0.569649
# 28  110813   0.054420
# 29   66190   0.233198
# 30  252674  15.141033
# 31  512810   0.315134
# 32  113725   2.974072
# 33   41874   8.024616
# 34   61210   0.334840
# 35   41725   0.670065
# 36  177958   1.454059
# 37   53907   0.104849
# 38  137627   0.856539
# 39  485002   0.947022
# 40   19441   0.056655
# 41  169079   0.093830
# 42  150554   0.123857
# 43   37000   1.110399
# 44   91195   0.072644
# 45   76402   1.225673
# 46  210236   0.281911
# 47  229351   0.000000
# 48  273976   1.513046
# 49   97966   2.676689
