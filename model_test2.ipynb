# %% [markdown]
# # 0. Dependancy

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/!_2022_fall/PDSP/kaggle/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/!_2022_fall/PDSP/kaggle

# %% [markdown]
# ### import package

# %%
import re
import requests
from bs4 import BeautifulSoup

import pandas as pd
from scipy.spatial import distance
from gensim.models import FastText
from textblob import TextBlob

from keras.preprocessing.text import Tokenizer
import re
import nltk
from string import punctuation 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import WordPunctTokenizer

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
en_stop = set(nltk.corpus.stopwords.words('english'))
nltk.download('averaged_perceptron_tagger')

# %% [markdown]
# # 1. load dataset & model

# %%
# read recipe csv file
df_recipe = pd.read_csv("./data/recipes_test.csv")
df_emissions = pd.read_csv("./data/emissions.csv")

# %%
#loaded_model = FastText.load('./model/fooddotcom_model')
loaded_model = FastText.load('./model/fooddotcom_v3')
print(loaded_model)
# Out:
# FastText(vocab=19610, size=200, alpha=0.025)

# %% [markdown]
# # 2. data preparation

# %% [markdown]
# ### build word-vector of ingredients in DB

# %%
# list of unique ingredient name in db (total 441)
ing_db_words = df_emissions['ingredient'].unique()

# list of word-vector of ingredient name in db (total 441)
ing_db_vecs = []
for ing in ing_db_words:
    ing_db_vecs.append(loaded_model.wv.get_vector(ing))

# %% [markdown]
# ### scrapping clean data

# %%
def generate_query(name,id):
    name = name.split(" ")
    name = '-'.join(name)
    query = name + "-" + str(id)
    return query

def requestRecipeUrl(input:str):
    print(input)
    # request by url 'https://www.food.com/recipe/' + name + id
    url = 'https://www.food.com/recipe/' + input 
    r = requests.get(url)
    # get a correct url and scale to create full url
    html_doc = r.text
    soup = BeautifulSoup(html_doc, features="html.parser")
    serves = soup.find(class_="value svelte-1o10zxc").string
    
    if len(serves) > 0 :
      if "/" in serves:
        serves = serves.split("/")
        serves = serves[0]+"%"+"2F"+serves[1]
        # 1%2F10
    print(serves)
    url_metric = r.url + '?units=metric&scale='+serves
    print(url_metric)
    # create html soup object to scrap 
    r = requests.get(url_metric)   
    html_doc = r.text
    soup = BeautifulSoup(html_doc, features="html.parser")

    return soup

# %%
def text_postprocessing(word):

  # remove special characters
  word = re.sub(r'\W', ' ', str(word))
  # remove numbers 
  word = re.sub('[0-9]+', '', word)
  # remove single characters
  word = re.sub(r'\s+[a-zA-Z]\s+', ' ', word)
  word = re.sub(r'\^[a-zA-Z]\s+', ' ', word)
  # substituting multiple spaces with single space
  word = re.sub(r'\s+', ' ', word, flags=re.I)
  # converting to lowercase
  word = word.lower()
  # remove stop words 
  tokens = word.split()
  clean = [token for token in tokens if len(token) > 2 if not token in en_stop]
  word = " ".join(clean)
  # leave only noun 
  word = TextBlob(word)
  pos = word.tags
  ##print(pos)
  word = [p[0] for p in pos if p[1] == 'NN' or p[1] == 'NNS']
  ##print(word)
  word = " ".join(word)
  ##print(word)

  return word

# %%
def parseRecipeName(soup:BeautifulSoup):
    # # INPUT(Constructor | BeautifulSoup) : BeautifulSoup constructor of Recipe URL html
    # # OUTPUT(tuple | string, List of dictionary) : Recipe Name
    recipeTitle = soup.title.text.split(' - Food.com')[0]
    return recipeTitle

def parseRecipeIngrd(soup:BeautifulSoup):
    # # INPUT(Constructor | BeautifulSoup) : BeautifulSoup constructor of Recipe URL html
    # # OUTPUT(List of dictionary) : Ingredients List
    ingrdList = findIngrd(soup)
    return ingrdList

def findIngrd(soup:BeautifulSoup):
    # # INPUT(Constructor | BeautifulSoup) : BeautifulSoup constructor of Recipe URL html
    # # OUTPUT(List of dictionary) : Ingredient Information List
    # #                              {'ingredient' : string, 'quantity' : float, 'unit' : string}

    ingrdList = []

    ultag = soup.find('ul', {'class': re.compile('^ingredient-list')})
    i = 0
    for litag in ultag.find_all('li'):
        # print(f"{i+1}/{len(ultag.find_all('li'))}")
        quant_obj = litag.find('span', {'class': re.compile('quantity')})
        ingrd_obj = litag.find('span', {'class': re.compile('text')})

        # CHECK : the item of list is the information of an ingredient.   
        if (quant_obj != None) and (ingrd_obj != None):
            if "/" in quant_obj.text:
              q_str = quant_obj.text.split("/")
              q = float(q_str [0])/float(q_str [1])
            elif "⁄" in quant_obj.text:
              q_str = quant_obj.text.split("⁄")
              q = float(q_str [0])/float(q_str [1])
            elif "-" in quant_obj.text:
              q_str = quant_obj.text.split("-")
              q = (float(q_str [0])+float(q_str [1]))/2
            elif quant_obj.text == '':
              q = 0
            else : 
              q = float(quant_obj.text)
            
            # ASSUME : If there is no unit, the unit as 'ea'
            _u = ingrd_obj.text.split()[0]
            u = _u if (_u =='ml' or _u =='g') else 'ea'

            # CHECK : the ingredient has a url for a detail.
            ingrdPage = ingrd_obj.find('a')
            if (ingrdPage != None):
                sub_url = ingrdPage['href']
                # CHECK : the ingrdient url is a Ingredient Detail page
                if ('about' in sub_url):
                    sub_url ='https://www.food.com' + sub_url
                    sub_r = requests.get(sub_url)
                    sub_html_doc = sub_r.text
                    sub_soup = BeautifulSoup(sub_html_doc, features="html.parser")
                    ingrd = sub_soup.find('h1').text

                    ingrdList.append({'ingredient' : ingrd.lower(), 'quantity' : q, 'unit' : u})
                else:
                    True
                    # TODO [CORNER CASE] Recursive Call of Scraping Recipe Page. Skip now.
            else:
                # TODO [CORNER CASE] case for the ingredient doesn't have a url link
                ingrd = ingrd_obj.text
                ingrd = text_postprocessing(ingrd)
                ingrdList.append({'ingredient' : ingrd, 'quantity' : q, 'unit' : u})
                True
        else:
            True
        i+=1

    return ingrdList

# %% [markdown]
# # 3. find similar words

# %%
def replace_sim_words(input):
    for i, ing_org in enumerate(input):
        print("===="*20)
        print("Find most similar words of <<",ing_org['ingredient'],">> in DB")
        distances = []
        ing_org_vec = loaded_model.wv.get_vector(ing_org['ingredient'])   

        for ing_db_vec in ing_db_vecs:
            cos_sim= distance.cosine(ing_org_vec, ing_db_vec)
            distances.append(cos_sim)

        min_dis = min(distances)
        sim_word = ing_db_words[distances.index(min_dis)]
        print("found! We will repace it to <<",sim_word,">> !  similarity is", round(1-min_dis,4))

        if min_dis > 0.2 :
          print("but it looks not so similar :( we will mark as none from the recipe")
          input[i]['ingredient']= "none"
        else:
          input[i]['ingredient']= sim_word
        
    return input

# %% [markdown]
# # 4. Compute CO2 emission

# %%
# average weight of ingredient per unit tbale 
ea_to_g = {'egg': 60,
 'onion': 100 ,
 'lemon': 60,
 'garlic': 6,
 'potato': 200,
 'sweet pepper': 110,
 'zucchini': 200,
 'artichoke': 120,
 'tomato': 100,
 'cucumber': 200,
 'avocado': 150,
 'eggplant': 500,
 }

# %%
def compute_emission(input):
    n = len(input)
    recipes = input.copy()
    for i in range(n):
      if input[i]['ingredient'] == 'none':
        recipes.remove(input[i])
    emission = 0
    for recipe in recipes:
      # cornercae, if unit is ea, conver to gram
      if recipe['unit'] == 'ea' and recipe['quantity'] > 0: 
        if recipe['ingredient'] in ea_to_g:
          print("corner case: ", recipe['ingredient'])
          recipe['quantity'] *= ea_to_g[recipe['ingredient']] 
          
      emission += recipe['quantity']*(df_emissions.loc[df_emissions['ingredient'] == recipe['ingredient'], 'emissions'].iloc[0])
    print(recipes)
    return emission

# %% [markdown]
# # 5. test file run

# %%
recipe_names = df_recipe['name']
recipe_ids = df_recipe['id']
emissions = []

for name,id in zip(recipe_names,recipe_ids):
    query = generate_query(name,id)
    soup = requestRecipeUrl(query)
    recipe = findIngrd(soup)
    print(recipe)
    recipe_new = replace_sim_words(recipe)
    emission = compute_emission(recipe_new)
    emissions.append(emission)
# Out:
# pretty-freaking-awesome--pulled-pork--crock-pot-484624
# 6
# https://www.food.com/recipe/pretty-freaking-awesome-pulled-pork-crock-pot-484624?units=metric&scale=6
# [{'ingredient': 'pork butt', 'quantity': 1587.565, 'unit': 'g'}, {'ingredient': 'onion', 'quantity': 2.0, 'unit': 'ea'}, {'ingredient': 'ginger ale', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'barbecue sauce', 'quantity': 453.59, 'unit': 'g'}, {'ingredient': 'brown sugar', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'sugar', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'paprika', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'pepper', 'quantity': 4.92, 'unit': 'ml'}, {'ingredient': 'mustard, seed and powder', 'quantity': 4.92, 'unit': 'ml'}, {'ingredient': 'cayenne pepper', 'quantity': 1.23, 'unit': 'ml'}]
# ================================================================================
# Find most similar words of << pork butt >> in DB
# found! We will repace it to << pork >> !  similarity is 0.8421
# ================================================================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 1
# ================================================================================
# Find most similar words of << ginger ale >> in DB
# found! We will repace it to << ginger >> !  similarity is 0.9145
# ================================================================================
# Find most similar words of << barbecue sauce >> in DB
# found! We will repace it to << barbecue sauce >> !  similarity is 1
# ================================================================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !  similarity is 1
# ================================================================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 1
# ================================================================================
# Find most similar words of << paprika >> in DB
# found! We will repace it to << paprika >> !  similarity is 1
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# ================================================================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 1
# ================================================================================
# Find most similar words of << mustard, seed and powder >> in DB
# found! We will repace it to << mustard seeds >> !  similarity is 0.8027
# ================================================================================
# Find most similar words of << cayenne pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0.8604
# corner case:  onion
# [{'ingredient': 'pork', 'quantity': 1587.565, 'unit': 'g'}, {'ingredient': 'onion', 'quantity': 200.0, 'unit': 'ea'}, {'ingredient': 'ginger', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'barbecue sauce', 'quantity': 453.59, 'unit': 'g'}, {'ingredient': 'brown sugar', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'sugar', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'paprika', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'pepper', 'quantity': 4.92, 'unit': 'ml'}, {'ingredient': 'mustard seeds', 'quantity': 4.92, 'unit': 'ml'}, {'ingredient': 'pepper', 'quantity': 1.23, 'unit': 'ml'}]
# acadia-s-eggplant-parmesan-399771
# 6
# https://www.food.com/recipe/acadias-eggplant-parmesan-399771?units=metric&scale=6
# [{'ingredient': 'salt', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'butter', 'quantity': 29.58, 'unit': 'ml'}, {'ingredient': 'eggplant', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'marinara sauce', 'quantity': 226.79, 'unit': 'g'}, {'ingredient': 'mozzarella', 'quantity': 226.79, 'unit': 'g'}, {'ingredient': 'parmesan cheese', 'quantity': 14.79, 'unit': 'ml'}]
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# ================================================================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 1
# ================================================================================
# Find most similar words of << eggplant >> in DB
# found! We will repace it to << eggplant >> !  similarity is 1
# ================================================================================
# Find most similar words of << marinara sauce >> in DB
# found! We will repace it to << barbecue sauce >> !  similarity is 0.7572
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << mozzarella >> in DB
# found! We will repace it to << mozzarella >> !  similarity is 1
# ================================================================================
# Find most similar words of << parmesan cheese >> in DB
# found! We will repace it to << parmesan >> !  similarity is 0.8816
# corner case:  eggplant
# [{'ingredient': 'salt', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'butter', 'quantity': 29.58, 'unit': 'ml'}, {'ingredient': 'eggplant', 'quantity': 500.0, 'unit': 'ea'}, {'ingredient': 'mozzarella', 'quantity': 226.79, 'unit': 'g'}, {'ingredient': 'parmesan', 'quantity': 14.79, 'unit': 'ml'}]
# african-chicken-curry-455721
# 4
# https://www.food.com/recipe/african-chicken-curry-455721?units=metric&scale=4
# [{'ingredient': 'olive oil', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'onion', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'garlic', 'quantity': 2.0, 'unit': 'ea'}, {'ingredient': 'bay leaf', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'tomato', 'quantity': 411.06, 'unit': 'g'}, {'ingredient': 'curry powder', 'quantity': 9.85, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 0.61, 'unit': 'ml'}, {'ingredient': 'chicken', 'quantity': 1133.975, 'unit': 'g'}, {'ingredient': 'coconut milk or cream', 'quantity': 396.89, 'unit': 'g'}, {'ingredient': 'lemon', 'quantity': 1.0, 'unit': 'ea'}]
# ================================================================================
# Find most similar words of << olive oil >> in DB
# found! We will repace it to << olive oil >> !  similarity is 1
# ================================================================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 1
# ================================================================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 1
# ================================================================================
# Find most similar words of << bay leaf >> in DB
# found! We will repace it to << baby peas >> !  similarity is 0.466
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << tomato >> in DB
# found! We will repace it to << tomato >> !  similarity is 1
# ================================================================================
# Find most similar words of << curry powder >> in DB
# found! We will repace it to << cocoa powder >> !  similarity is 0.7678
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# ================================================================================
# Find most similar words of << chicken >> in DB
# found! We will repace it to << chicken >> !  similarity is 1
# ================================================================================
# Find most similar words of << coconut milk or cream >> in DB
# found! We will repace it to << coconut milk >> !  similarity is 0.8783
# ================================================================================
# Find most similar words of << lemon >> in DB
# found! We will repace it to << lemon >> !  similarity is 1
# corner case:  onion
# corner case:  garlic
# corner case:  lemon
# [{'ingredient': 'olive oil', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'onion', 'quantity': 100.0, 'unit': 'ea'}, {'ingredient': 'garlic', 'quantity': 12.0, 'unit': 'ea'}, {'ingredient': 'tomato', 'quantity': 411.06, 'unit': 'g'}, {'ingredient': 'salt', 'quantity': 0.61, 'unit': 'ml'}, {'ingredient': 'chicken', 'quantity': 1133.975, 'unit': 'g'}, {'ingredient': 'coconut milk', 'quantity': 396.89, 'unit': 'g'}, {'ingredient': 'lemon', 'quantity': 60.0, 'unit': 'ea'}]
# african-mint-chutney-454994
# 8
# https://www.food.com/recipe/african-mint-chutney-454994?units=metric&scale=8
# [{'ingredient': 'peanut', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'garlic', 'quantity': 3.0, 'unit': 'ea'}, {'ingredient': 'chili', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'mint', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'coriander seeds', 'quantity': 9.85, 'unit': 'ml'}, {'ingredient': 'vinegar', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'lime', 'quantity': 44.37, 'unit': 'ml'}, {'ingredient': 'yogurt', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'pepper', 'quantity': 0, 'unit': 'ea'}]
# ================================================================================
# Find most similar words of << peanut >> in DB
# found! We will repace it to << peanuts >> !  similarity is 0.9572
# ================================================================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 1
# ================================================================================
# Find most similar words of << chili >> in DB
# found! We will repace it to << chili >> !  similarity is 1
# ================================================================================
# Find most similar words of << mint >> in DB
# found! We will repace it to << mint >> !  similarity is 1
# ================================================================================
# Find most similar words of << coriander seeds >> in DB
# found! We will repace it to << chia seeds >> !  similarity is 0.7254
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << vinegar >> in DB
# found! We will repace it to << white wine vinegar >> !  similarity is 0.8771
# ================================================================================
# Find most similar words of << lime >> in DB
# found! We will repace it to << lime >> !  similarity is 1
# ================================================================================
# Find most similar words of << yogurt >> in DB
# found! We will repace it to << yogurt >> !  similarity is 1
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# ================================================================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 1
# corner case:  garlic
# [{'ingredient': 'peanuts', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'garlic', 'quantity': 18.0, 'unit': 'ea'}, {'ingredient': 'chili', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'mint', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'white wine vinegar', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'lime', 'quantity': 44.37, 'unit': 'ml'}, {'ingredient': 'yogurt', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'pepper', 'quantity': 0, 'unit': 'ea'}]
# alyssa-s-favorite-fish-361646
# 4-6
# https://www.food.com/recipe/alyssas-favorite-fish-361646?units=metric&scale=4-6
# [{'ingredient': 'salt breadcrumbs', 'quantity': 354.88, 'unit': 'ml'}, {'ingredient': 'butter', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'lemon juice', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'chives', 'quantity': 4.92, 'unit': 'ml'}, {'ingredient': 'piece scrod fillets fish choice', 'quantity': 5.0, 'unit': 'ea'}, {'ingredient': 'pam cooking spray', 'quantity': 0, 'unit': 'ea'}]
# ================================================================================
# Find most similar words of << salt breadcrumbs >> in DB
# found! We will repace it to << salt >> !  similarity is 0.6726
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 1
# ================================================================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !  similarity is 1
# ================================================================================
# Find most similar words of << chives >> in DB
# found! We will repace it to << chives >> !  similarity is 1
# ================================================================================
# Find most similar words of << piece scrod fillets fish choice >> in DB
# found! We will repace it to << catfish >> !  similarity is 0.6208
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << pam cooking spray >> in DB
# found! We will repace it to << sprat >> !  similarity is 0.631
# but it looks not so similar :( we will mark as none from the recipe
# [{'ingredient': 'butter', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'lemon juice', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'chives', 'quantity': 4.92, 'unit': 'ml'}]
# another-mint-chutney-26219
# 1%2F2
# https://www.food.com/recipe/another-mint-chutney-26219?units=metric&scale=1%2F2
# [{'ingredient': 'mint', 'quantity': 125.0, 'unit': 'g'}, {'ingredient': 'chile pepper', 'quantity': 3.0, 'unit': 'ea'}, {'ingredient': 'green onion', 'quantity': 3.0, 'unit': 'ea'}, {'ingredient': 'vinegar', 'quantity': 4.0, 'unit': 'ea'}, {'ingredient': 'sugar', 'quantity': 2.0, 'unit': 'ea'}, {'ingredient': 'salt', 'quantity': 0.5, 'unit': 'ea'}]
# ================================================================================
# Find most similar words of << mint >> in DB
# found! We will repace it to << mint >> !  similarity is 1
# ================================================================================
# Find most similar words of << chile pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0.8708
# ================================================================================
# Find most similar words of << green onion >> in DB
# found! We will repace it to << green onion >> !  similarity is 1
# ================================================================================
# Find most similar words of << vinegar >> in DB
# found! We will repace it to << white wine vinegar >> !  similarity is 0.8771
# ================================================================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 1
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# [{'ingredient': 'mint', 'quantity': 125.0, 'unit': 'g'}, {'ingredient': 'pepper', 'quantity': 3.0, 'unit': 'ea'}, {'ingredient': 'green onion', 'quantity': 3.0, 'unit': 'ea'}, {'ingredient': 'white wine vinegar', 'quantity': 4.0, 'unit': 'ea'}, {'ingredient': 'sugar', 'quantity': 2.0, 'unit': 'ea'}, {'ingredient': 'salt', 'quantity': 0.5, 'unit': 'ea'}]
# apple-cheese-muffins-53252
# 18
# https://www.food.com/recipe/apple-cheese-muffins-53252?units=metric&scale=18
# [{'ingredient': 'margarine', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'sugar', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'egg', 'quantity': 2.0, 'unit': 'ea'}, {'ingredient': 'flour', 'quantity': 354.88, 'unit': 'ml'}, {'ingredient': 'baking soda', 'quantity': 4.92, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'oatmeal', 'quantity': 177.44, 'unit': 'ml'}, {'ingredient': 'cheddar cheese', 'quantity': 158.51, 'unit': 'ml'}, {'ingredient': 'milk', 'quantity': 59.14, 'unit': 'ml'}, {'ingredient': 'apple', 'quantity': 236.59, 'unit': 'ea'}, {'ingredient': 'nuts', 'quantity': 118.29, 'unit': 'ml'}]
# ================================================================================
# Find most similar words of << margarine >> in DB
# found! We will repace it to << half-fat margarine >> !  similarity is 0.8523
# ================================================================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 1
# ================================================================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 1
# ================================================================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.8824
# ================================================================================
# Find most similar words of << baking soda >> in DB
# found! We will repace it to << baking soda >> !  similarity is 1
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# ================================================================================
# Find most similar words of << oatmeal >> in DB
# found! We will repace it to << oatmeal >> !  similarity is 1
# ================================================================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !  similarity is 1
# ================================================================================
# Find most similar words of << milk >> in DB
# found! We will repace it to << milk >> !  similarity is 1
# ================================================================================
# Find most similar words of << apple >> in DB
# found! We will repace it to << apple >> !  similarity is 1
# ================================================================================
# Find most similar words of << nuts >> in DB
# found! We will repace it to << nuts >> !  similarity is 1
# corner case:  egg
# [{'ingredient': 'half-fat margarine', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'sugar', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'egg', 'quantity': 120.0, 'unit': 'ea'}, {'ingredient': 'lupin flour', 'quantity': 354.88, 'unit': 'ml'}, {'ingredient': 'baking soda', 'quantity': 4.92, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'oatmeal', 'quantity': 177.44, 'unit': 'ml'}, {'ingredient': 'cheddar cheese', 'quantity': 158.51, 'unit': 'ml'}, {'ingredient': 'milk', 'quantity': 59.14, 'unit': 'ml'}, {'ingredient': 'apple', 'quantity': 236.59, 'unit': 'ea'}, {'ingredient': 'nuts', 'quantity': 118.29, 'unit': 'ml'}]
# asparagus-in-creamy-orange-maltaise-butter-sauce-186382
# 6
# https://www.food.com/recipe/asparagus-in-creamy-orange-maltaise-butter-sauce-186382?units=metric&scale=6
# [{'ingredient': 'asparagus', 'quantity': 450.0, 'unit': 'g'}, {'ingredient': 'egg yolks', 'quantity': 3.0, 'unit': 'ea'}, {'ingredient': 'orange', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'salt', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'pepper', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'butter', 'quantity': 100.0, 'unit': 'g'}, {'ingredient': 'lemon juice', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'heavy cream', 'quantity': 44.37, 'unit': 'ml'}, {'ingredient': 'orange rind twists', 'quantity': 0, 'unit': 'ea'}]
# ================================================================================
# Find most similar words of << asparagus >> in DB
# found! We will repace it to << green asparagus >> !  similarity is 0.8677
# ================================================================================
# Find most similar words of << egg yolks >> in DB
# found! We will repace it to << egg >> !  similarity is 0.5757
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << orange >> in DB
# found! We will repace it to << orange >> !  similarity is 1
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# ================================================================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 1
# ================================================================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 1
# ================================================================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !  similarity is 1
# ================================================================================
# Find most similar words of << heavy cream >> in DB
# found! We will repace it to << heavy cream milk >> !  similarity is 0.8305
# ================================================================================
# Find most similar words of << orange rind twists >> in DB
# found! We will repace it to << orange >> !  similarity is 0.8493
# [{'ingredient': 'green asparagus', 'quantity': 450.0, 'unit': 'g'}, {'ingredient': 'orange', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'salt', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'pepper', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'butter', 'quantity': 100.0, 'unit': 'g'}, {'ingredient': 'lemon juice', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'heavy cream milk', 'quantity': 44.37, 'unit': 'ml'}, {'ingredient': 'orange', 'quantity': 0, 'unit': 'ea'}]
# aunty-diane-s-yummy-burgers-130632
# 6
# https://www.food.com/recipe/aunty-dianes-yummy-burgers-130632?units=metric&scale=6
# [{'ingredient': 'beef', 'quantity': 453.59, 'unit': 'g'}, {'ingredient': 'pork', 'quantity': 453.59, 'unit': 'g'}, {'ingredient': 'onion', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'garlic powder', 'quantity': 4.92, 'unit': 'ml'}, {'ingredient': 'oatmeal', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'salt pepper', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'egg', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'water', 'quantity': 59.14, 'unit': 'ml'}]
# ================================================================================
# Find most similar words of << beef >> in DB
# found! We will repace it to << beef >> !  similarity is 1
# ================================================================================
# Find most similar words of << pork >> in DB
# found! We will repace it to << pork >> !  similarity is 1
# ================================================================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 1
# ================================================================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.8217
# ================================================================================
# Find most similar words of << oatmeal >> in DB
# found! We will repace it to << oatmeal >> !  similarity is 1
# ================================================================================
# Find most similar words of << salt pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 0.8393
# ================================================================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 1
# ================================================================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !  similarity is 0.8775
# corner case:  egg
# [{'ingredient': 'beef', 'quantity': 453.59, 'unit': 'g'}, {'ingredient': 'pork', 'quantity': 453.59, 'unit': 'g'}, {'ingredient': 'onion', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'onion powder', 'quantity': 4.92, 'unit': 'ml'}, {'ingredient': 'oatmeal', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'pepper', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'egg', 'quantity': 60.0, 'unit': 'ea'}, {'ingredient': 'tap water', 'quantity': 59.14, 'unit': 'ml'}]
# autumn-tea-257067
# 3
# https://www.food.com/recipe/autumn-tea-257067?units=metric&scale=3
# [{'ingredient': 'tea', 'quantity': 5.0, 'unit': 'ea'}, {'ingredient': 'water', 'quantity': 1182.95, 'unit': 'ml'}, {'ingredient': 'apple juice', 'quantity': 1182.95, 'unit': 'ml'}, {'ingredient': 'cranberry', 'quantity': 473.18, 'unit': 'ml'}, {'ingredient': 'sugar', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'lemon juice', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'pumpkin pie spice', 'quantity': 1.23, 'unit': 'ml'}]
# ================================================================================
# Find most similar words of << tea >> in DB
# found! We will repace it to << tea >> !  similarity is 1
# ================================================================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !  similarity is 0.8775
# ================================================================================
# Find most similar words of << apple juice >> in DB
# found! We will repace it to << apple juice >> !  similarity is 1
# ================================================================================
# Find most similar words of << cranberry >> in DB
# found! We will repace it to << cranberries >> !  similarity is 0.8656
# ================================================================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 1
# ================================================================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !  similarity is 1
# ================================================================================
# Find most similar words of << pumpkin pie spice >> in DB
# found! We will repace it to << pumpkin >> !  similarity is 0.833
# [{'ingredient': 'tea', 'quantity': 5.0, 'unit': 'ea'}, {'ingredient': 'tap water', 'quantity': 1182.95, 'unit': 'ml'}, {'ingredient': 'apple juice', 'quantity': 1182.95, 'unit': 'ml'}, {'ingredient': 'cranberries', 'quantity': 473.18, 'unit': 'ml'}, {'ingredient': 'sugar', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'lemon juice', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'pumpkin', 'quantity': 1.23, 'unit': 'ml'}]
# avocado-sandwiches-28149
# 4
# https://www.food.com/recipe/avocado-sandwiches-28149?units=metric&scale=4
# [{'ingredient': 'bacon', 'quantity': 453.59, 'unit': 'g'}, {'ingredient': 'avocado', 'quantity': 2.0, 'unit': 'ea'}, {'ingredient': 'salt taste', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'mayonnaise', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'lemon juice', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'slice wheat bread', 'quantity': 8.0, 'unit': 'ea'}]
# ================================================================================
# Find most similar words of << bacon >> in DB
# found! We will repace it to << bacon >> !  similarity is 1
# ================================================================================
# Find most similar words of << avocado >> in DB
# found! We will repace it to << avocado >> !  similarity is 1
# ================================================================================
# Find most similar words of << salt taste >> in DB
# found! We will repace it to << salt >> !  similarity is 0.6868
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << mayonnaise >> in DB
# found! We will repace it to << mayonnaise >> !  similarity is 1
# ================================================================================
# Find most similar words of << lemon juice >> in DB
# found! We will repace it to << lemon juice >> !  similarity is 1
# ================================================================================
# Find most similar words of << slice wheat bread >> in DB
# found! We will repace it to << wheat bread >> !  similarity is 0.7635
# but it looks not so similar :( we will mark as none from the recipe
# corner case:  avocado
# [{'ingredient': 'bacon', 'quantity': 453.59, 'unit': 'g'}, {'ingredient': 'avocado', 'quantity': 300.0, 'unit': 'ea'}, {'ingredient': 'mayonnaise', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'lemon juice', 'quantity': 14.79, 'unit': 'ml'}]
# banana-buttermilk-pancakes-112082
# 6
# https://www.food.com/recipe/banana-buttermilk-pancakes-112082?units=metric&scale=6
# [{'ingredient': 'flour', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'flour', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'brown sugar', 'quantity': 44.37, 'unit': 'ml'}, {'ingredient': 'baking powder', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'baking soda', 'quantity': 1.23, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 1.23, 'unit': 'ml'}, {'ingredient': 'buttermilk', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'egg', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'butter', 'quantity': 22.18, 'unit': 'ml'}, {'ingredient': 'canola oil', 'quantity': 9.85, 'unit': 'ml'}, {'ingredient': 'banana', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'maple syrup', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'walnut', 'quantity': 0, 'unit': 'ea'}]
# ================================================================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.8824
# ================================================================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.8824
# ================================================================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !  similarity is 1
# ================================================================================
# Find most similar words of << baking powder >> in DB
# found! We will repace it to << baking powder >> !  similarity is 1
# ================================================================================
# Find most similar words of << baking soda >> in DB
# found! We will repace it to << baking soda >> !  similarity is 1
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# ================================================================================
# Find most similar words of << buttermilk >> in DB
# found! We will repace it to << buttermilk >> !  similarity is 1
# ================================================================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 1
# ================================================================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 1
# ================================================================================
# Find most similar words of << canola oil >> in DB
# found! We will repace it to << oil >> !  similarity is 0.6363
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << banana >> in DB
# found! We will repace it to << banana >> !  similarity is 1
# ================================================================================
# Find most similar words of << maple syrup >> in DB
# found! We will repace it to << agave syrup >> !  similarity is 0.8175
# ================================================================================
# Find most similar words of << walnut >> in DB
# found! We will repace it to << walnuts >> !  similarity is 0.9403
# corner case:  egg
# [{'ingredient': 'lupin flour', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'lupin flour', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'brown sugar', 'quantity': 44.37, 'unit': 'ml'}, {'ingredient': 'baking powder', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'baking soda', 'quantity': 1.23, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 1.23, 'unit': 'ml'}, {'ingredient': 'buttermilk', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'egg', 'quantity': 60.0, 'unit': 'ea'}, {'ingredient': 'butter', 'quantity': 22.18, 'unit': 'ml'}, {'ingredient': 'banana', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'agave syrup', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'walnuts', 'quantity': 0, 'unit': 'ea'}]
# barbecue-chicken-and-rice-154088
# 6
# https://www.food.com/recipe/barbecue-chicken-and-rice-154088?units=metric&scale=6
# [{'ingredient': 'chicken', 'quantity': 1133.98, 'unit': 'g'}, {'ingredient': 'olive oil', 'quantity': 29.58, 'unit': 'ml'}, {'ingredient': 'barbecue sauce', 'quantity': 295.73, 'unit': 'ml'}, {'ingredient': 'water', 'quantity': 177.44, 'unit': 'ml'}, {'ingredient': 'rice', 'quantity': 354.88, 'unit': 'ml'}, {'ingredient': 'corn', 'quantity': 236.59, 'unit': 'ml'}]
# ================================================================================
# Find most similar words of << chicken >> in DB
# found! We will repace it to << chicken >> !  similarity is 1
# ================================================================================
# Find most similar words of << olive oil >> in DB
# found! We will repace it to << olive oil >> !  similarity is 1
# ================================================================================
# Find most similar words of << barbecue sauce >> in DB
# found! We will repace it to << barbecue sauce >> !  similarity is 1
# ================================================================================
# Find most similar words of << water >> in DB
# found! We will repace it to << tap water >> !  similarity is 0.8775
# ================================================================================
# Find most similar words of << rice >> in DB
# found! We will repace it to << rice >> !  similarity is 1
# ================================================================================
# Find most similar words of << corn >> in DB
# found! We will repace it to << corn >> !  similarity is 1
# [{'ingredient': 'chicken', 'quantity': 1133.98, 'unit': 'g'}, {'ingredient': 'olive oil', 'quantity': 29.58, 'unit': 'ml'}, {'ingredient': 'barbecue sauce', 'quantity': 295.73, 'unit': 'ml'}, {'ingredient': 'tap water', 'quantity': 177.44, 'unit': 'ml'}, {'ingredient': 'rice', 'quantity': 354.88, 'unit': 'ml'}, {'ingredient': 'corn', 'quantity': 236.59, 'unit': 'ml'}]
# bbq-sauce-great-for-chicken-wings-313094
# 4
# https://www.food.com/recipe/bbq-sauce-great-for-chicken-wings-313094?units=metric&scale=4
# [{'ingredient': 'cider vinegar', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'worcestershire sauce', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'ketchup', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'brown sugar', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'molasses', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'onion', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'garlic powder', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'butter', 'quantity': 29.58, 'unit': 'ml'}, {'ingredient': 'chili powder', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'pepper', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'celery seed', 'quantity': 4.92, 'unit': 'ml'}]
# ================================================================================
# Find most similar words of << cider vinegar >> in DB
# found! We will repace it to << apple vinegar >> !  similarity is 0.8454
# ================================================================================
# Find most similar words of << worcestershire sauce >> in DB
# found! We will repace it to << tabasco sauce >> !  similarity is 0.7901
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << ketchup >> in DB
# found! We will repace it to << ketchup >> !  similarity is 1
# ================================================================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !  similarity is 1
# ================================================================================
# Find most similar words of << molasses >> in DB
# found! We will repace it to << granulated sugar >> !  similarity is 0.6325
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 1
# ================================================================================
# Find most similar words of << garlic powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.8217
# ================================================================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 1
# ================================================================================
# Find most similar words of << chili powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.8086
# ================================================================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 1
# ================================================================================
# Find most similar words of << celery seed >> in DB
# found! We will repace it to << celery >> !  similarity is 0.7925
# but it looks not so similar :( we will mark as none from the recipe
# [{'ingredient': 'apple vinegar', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'ketchup', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'brown sugar', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'onion', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'onion powder', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'butter', 'quantity': 29.58, 'unit': 'ml'}, {'ingredient': 'onion powder', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'pepper', 'quantity': 2.46, 'unit': 'ml'}]
# beans-and-rice-and-corn-382812
# 4
# https://www.food.com/recipe/beans-and-rice-and-corn-382812?units=metric&scale=4
# [{'ingredient': 'onion', 'quantity': 59.14, 'unit': 'ml'}, {'ingredient': 'green onion', 'quantity': 59.14, 'unit': 'ml'}, {'ingredient': 'garlic', 'quantity': 3.0, 'unit': 'ea'}, {'ingredient': 'rice', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'broth', 'quantity': 591.47, 'unit': 'ml'}, {'ingredient': 'black bean', 'quantity': 425.24, 'unit': 'g'}, {'ingredient': 'corn', 'quantity': 446.5, 'unit': 'g'}, {'ingredient': 'salt', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'pepper', 'quantity': 0, 'unit': 'ea'}]
# ================================================================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 1
# ================================================================================
# Find most similar words of << green onion >> in DB
# found! We will repace it to << green onion >> !  similarity is 1
# ================================================================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 1
# ================================================================================
# Find most similar words of << rice >> in DB
# found! We will repace it to << rice >> !  similarity is 1
# ================================================================================
# Find most similar words of << broth >> in DB
# found! We will repace it to << beef broth >> !  similarity is 0.8459
# ================================================================================
# Find most similar words of << black bean >> in DB
# found! We will repace it to << black beans >> !  similarity is 0.9167
# ================================================================================
# Find most similar words of << corn >> in DB
# found! We will repace it to << corn >> !  similarity is 1
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# ================================================================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 1
# corner case:  garlic
# [{'ingredient': 'onion', 'quantity': 59.14, 'unit': 'ml'}, {'ingredient': 'green onion', 'quantity': 59.14, 'unit': 'ml'}, {'ingredient': 'garlic', 'quantity': 18.0, 'unit': 'ea'}, {'ingredient': 'rice', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'beef broth', 'quantity': 591.47, 'unit': 'ml'}, {'ingredient': 'black beans', 'quantity': 425.24, 'unit': 'g'}, {'ingredient': 'corn', 'quantity': 446.5, 'unit': 'g'}, {'ingredient': 'salt', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'pepper', 'quantity': 0, 'unit': 'ea'}]
# becky-s-apple-crisp-64322
# 1
# https://www.food.com/recipe/beckys-apple-crisp-64322?units=metric&scale=1
# [{'ingredient': 'apple', 'quantity': 7.0, 'unit': 'ea'}, {'ingredient': 'cinnamon', 'quantity': 1.23, 'unit': 'ml'}, {'ingredient': 'sugar', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'brown sugar', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'oatmeal', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'flour', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'butter', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'ice cream', 'quantity': 0, 'unit': 'ea'}]
# ================================================================================
# Find most similar words of << apple >> in DB
# found! We will repace it to << apple >> !  similarity is 1
# ================================================================================
# Find most similar words of << cinnamon >> in DB
# found! We will repace it to << cinnamon >> !  similarity is 1
# ================================================================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 1
# ================================================================================
# Find most similar words of << brown sugar >> in DB
# found! We will repace it to << brown sugar >> !  similarity is 1
# ================================================================================
# Find most similar words of << oatmeal >> in DB
# found! We will repace it to << oatmeal >> !  similarity is 1
# ================================================================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.8824
# ================================================================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 1
# ================================================================================
# Find most similar words of << ice cream >> in DB
# found! We will repace it to << cream >> !  similarity is 0.914
# [{'ingredient': 'apple', 'quantity': 7.0, 'unit': 'ea'}, {'ingredient': 'cinnamon', 'quantity': 1.23, 'unit': 'ml'}, {'ingredient': 'sugar', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'brown sugar', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'oatmeal', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'lupin flour', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'butter', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'cream', 'quantity': 0, 'unit': 'ea'}]
# beef-chili-n-cheddar-potatoes-10328
# 4
# https://www.food.com/recipe/beef-chilin-cheddar-potatoes-10328?units=metric&scale=4
# [{'ingredient': 'beef', 'quantity': 680.38, 'unit': 'g'}, {'ingredient': 'potato', 'quantity': 4.0, 'unit': 'ea'}, {'ingredient': 'chili powder', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'pink bean', 'quantity': 425.24, 'unit': 'g'}, {'ingredient': 'cheddar cheese', 'quantity': 354.88, 'unit': 'ml'}, {'ingredient': 'green onion', 'quantity': 59.14, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 2.46, 'unit': 'ml'}]
# ================================================================================
# Find most similar words of << beef >> in DB
# found! We will repace it to << beef >> !  similarity is 1
# ================================================================================
# Find most similar words of << potato >> in DB
# found! We will repace it to << potato >> !  similarity is 1
# ================================================================================
# Find most similar words of << chili powder >> in DB
# found! We will repace it to << onion powder >> !  similarity is 0.8086
# ================================================================================
# Find most similar words of << pink bean >> in DB
# found! We will repace it to << pinto beans >> !  similarity is 0.7606
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !  similarity is 1
# ================================================================================
# Find most similar words of << green onion >> in DB
# found! We will repace it to << green onion >> !  similarity is 1
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# corner case:  potato
# [{'ingredient': 'beef', 'quantity': 680.38, 'unit': 'g'}, {'ingredient': 'potato', 'quantity': 800.0, 'unit': 'ea'}, {'ingredient': 'onion powder', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'cheddar cheese', 'quantity': 354.88, 'unit': 'ml'}, {'ingredient': 'green onion', 'quantity': 59.14, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 2.46, 'unit': 'ml'}]
# beer-brine-274736
# 1
# https://www.food.com/recipe/beer-brine-274736?units=metric&scale=1
# ...
# Find most similar words of << vanilla >> in DB
# found! We will repace it to << vanilla >> !  similarity is 1
# ================================================================================
# Find most similar words of << oatmeal >> in DB
# found! We will repace it to << oatmeal >> !  similarity is 1
# ================================================================================
# Find most similar words of << raisin >> in DB
# found! We will repace it to << walnuts >> !  similarity is 0.6256
# but it looks not so similar :( we will mark as none from the recipe
# corner case:  egg
# [{'ingredient': 'lupin flour', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'baking powder', 'quantity': 4.92, 'unit': 'ml'}, {'ingredient': 'baking soda', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'butter', 'quantity': 29.58, 'unit': 'ml'}, {'ingredient': 'sugar', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'brown sugar', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'egg', 'quantity': 60.0, 'unit': 'ea'}, {'ingredient': 'vanilla', 'quantity': 4.92, 'unit': 'ml'}, {'ingredient': 'oatmeal', 'quantity': 315.37, 'unit': 'ml'}]
# original--nilla-banana-pudding-37000
# 1
# https://www.food.com/recipe/original-nilla-banana-pudding-37000?units=metric&scale=1
# [{'ingredient': 'sugar', 'quantity': 177.44, 'unit': 'ml'}, {'ingredient': 'flour', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 0.25, 'unit': 'ml'}, {'ingredient': 'egg', 'quantity': 3.0, 'unit': 'ea'}, {'ingredient': 'milk', 'quantity': 473.18, 'unit': 'ml'}, {'ingredient': 'vanilla', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'vanilla wafers', 'quantity': 45.0, 'unit': 'ea'}, {'ingredient': 'banana', 'quantity': 5.0, 'unit': 'ea'}]
# ================================================================================
# Find most similar words of << sugar >> in DB
# found! We will repace it to << sugar >> !  similarity is 1
# ================================================================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.8824
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# ================================================================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 1
# ================================================================================
# Find most similar words of << milk >> in DB
# found! We will repace it to << milk >> !  similarity is 1
# ================================================================================
# Find most similar words of << vanilla >> in DB
# found! We will repace it to << vanilla >> !  similarity is 1
# ================================================================================
# Find most similar words of << vanilla wafers >> in DB
# found! We will repace it to << vanilla >> !  similarity is 0.8778
# ================================================================================
# Find most similar words of << banana >> in DB
# found! We will repace it to << banana >> !  similarity is 1
# corner case:  egg
# [{'ingredient': 'sugar', 'quantity': 177.44, 'unit': 'ml'}, {'ingredient': 'lupin flour', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 0.25, 'unit': 'ml'}, {'ingredient': 'egg', 'quantity': 180.0, 'unit': 'ea'}, {'ingredient': 'milk', 'quantity': 473.18, 'unit': 'ml'}, {'ingredient': 'vanilla', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'vanilla', 'quantity': 45.0, 'unit': 'ea'}, {'ingredient': 'banana', 'quantity': 5.0, 'unit': 'ea'}]
# potato-and-red--pepper-frittata-91195
# 4
# https://www.food.com/recipe/potato-and-red-pepper-frittata-91195?units=metric&scale=4
# [{'ingredient': 'olive oil', 'quantity': 14.78, 'unit': 'ml'}, {'ingredient': 'onion', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'sweet pepper', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'potato', 'quantity': 2.0, 'unit': 'ea'}, {'ingredient': 'egg', 'quantity': 8.0, 'unit': 'ea'}, {'ingredient': 'salt', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'pepper', 'quantity': 0.61, 'unit': 'ml'}]
# ================================================================================
# Find most similar words of << olive oil >> in DB
# found! We will repace it to << olive oil >> !  similarity is 1
# ================================================================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 1
# ================================================================================
# Find most similar words of << sweet pepper >> in DB
# found! We will repace it to << sweet pepper >> !  similarity is 1
# ================================================================================
# Find most similar words of << potato >> in DB
# found! We will repace it to << potato >> !  similarity is 1
# ================================================================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 1
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# ================================================================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 1
# corner case:  onion
# corner case:  sweet pepper
# corner case:  potato
# corner case:  egg
# [{'ingredient': 'olive oil', 'quantity': 14.78, 'unit': 'ml'}, {'ingredient': 'onion', 'quantity': 100.0, 'unit': 'ea'}, {'ingredient': 'sweet pepper', 'quantity': 110.0, 'unit': 'ea'}, {'ingredient': 'potato', 'quantity': 400.0, 'unit': 'ea'}, {'ingredient': 'egg', 'quantity': 480.0, 'unit': 'ea'}, {'ingredient': 'salt', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'pepper', 'quantity': 0.61, 'unit': 'ml'}]
# sole-francese-76402
# 4
# https://www.food.com/recipe/sole-francese-76402?units=metric&scale=4
# [{'ingredient': 'dover thin', 'quantity': 453.59, 'unit': 'g'}, {'ingredient': 'flour', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'egg', 'quantity': 3.0, 'unit': 'ea'}, {'ingredient': 'parmesan cheese', 'quantity': 88.74, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'olive oil', 'quantity': 29.58, 'unit': 'ml'}, {'ingredient': 'butter', 'quantity': 29.58, 'unit': 'ml'}, {'ingredient': 'lemon', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'marsala', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'garlic', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'cornstarch', 'quantity': 14.79, 'unit': 'ml'}]
# ================================================================================
# Find most similar words of << dover thin >> in DB
# found! We will repace it to << ackee >> !  similarity is 0.272
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << flour >> in DB
# found! We will repace it to << lupin flour >> !  similarity is 0.8824
# ================================================================================
# Find most similar words of << egg >> in DB
# found! We will repace it to << egg >> !  similarity is 1
# ================================================================================
# Find most similar words of << parmesan cheese >> in DB
# found! We will repace it to << parmesan >> !  similarity is 0.8816
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# ================================================================================
# Find most similar words of << olive oil >> in DB
# found! We will repace it to << olive oil >> !  similarity is 1
# ================================================================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 1
# ================================================================================
# Find most similar words of << lemon >> in DB
# found! We will repace it to << lemon >> !  similarity is 1
# ================================================================================
# Find most similar words of << marsala >> in DB
# found! We will repace it to << marjoram >> !  similarity is 0.5815
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 1
# ================================================================================
# Find most similar words of << cornstarch >> in DB
# found! We will repace it to << cornstarch >> !  similarity is 1
# corner case:  egg
# corner case:  lemon
# corner case:  garlic
# [{'ingredient': 'lupin flour', 'quantity': 118.29, 'unit': 'ml'}, {'ingredient': 'egg', 'quantity': 180.0, 'unit': 'ea'}, {'ingredient': 'parmesan', 'quantity': 88.74, 'unit': 'ml'}, {'ingredient': 'salt', 'quantity': 2.46, 'unit': 'ml'}, {'ingredient': 'olive oil', 'quantity': 29.58, 'unit': 'ml'}, {'ingredient': 'butter', 'quantity': 29.58, 'unit': 'ml'}, {'ingredient': 'lemon', 'quantity': 60.0, 'unit': 'ea'}, {'ingredient': 'garlic', 'quantity': 6.0, 'unit': 'ea'}, {'ingredient': 'cornstarch', 'quantity': 14.79, 'unit': 'ml'}]
# soy-ginger-flank-steak-with-garlic-210236
# 6-8
# https://www.food.com/recipe/soy-ginger-flank-steak-with-garlic-210236?units=metric&scale=6-8
# [{'ingredient': 'soy sauce', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'honey', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'garlic', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'ginger', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'flank steak', 'quantity': 680.385, 'unit': 'g'}]
# ================================================================================
# Find most similar words of << soy sauce >> in DB
# found! We will repace it to << soy sauce >> !  similarity is 1
# ================================================================================
# Find most similar words of << honey >> in DB
# found! We will repace it to << honey >> !  similarity is 1
# ================================================================================
# Find most similar words of << garlic >> in DB
# found! We will repace it to << garlic >> !  similarity is 1
# ================================================================================
# Find most similar words of << ginger >> in DB
# found! We will repace it to << ginger >> !  similarity is 1
# ================================================================================
# Find most similar words of << flank steak >> in DB
# found! We will repace it to << swordfish >> !  similarity is 0.5609
# but it looks not so similar :( we will mark as none from the recipe
# [{'ingredient': 'soy sauce', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'honey', 'quantity': 78.78, 'unit': 'ml'}, {'ingredient': 'garlic', 'quantity': 14.79, 'unit': 'ml'}, {'ingredient': 'ginger', 'quantity': 14.79, 'unit': 'ml'}]
# sparkling-paradise-229351
# 1
# https://www.food.com/recipe/sparkling-paradise-229351?units=metric&scale=1
# [{'ingredient': 'paradise mango rum liqueur', 'quantity': 85.04, 'unit': 'g'}, {'ingredient': 'lime soda club soda taste', 'quantity': 85.04, 'unit': 'g'}]
# ================================================================================
# Find most similar words of << paradise mango rum liqueur >> in DB
# found! We will repace it to << mango >> !  similarity is 0.653
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << lime soda club soda taste >> in DB
# found! We will repace it to << coffee powder >> !  similarity is 0.5723
# but it looks not so similar :( we will mark as none from the recipe
# []
# the-simplest-tomato-sauce-ever---marcella-hazan-273976
# 4
# https://www.food.com/recipe/the-simplest-tomato-sauce-ever-marcella-hazan-273976?units=metric&scale=4
# [{'ingredient': 'plum tomato', 'quantity': 473.18, 'unit': 'ml'}, {'ingredient': 'butter', 'quantity': 73.94, 'unit': 'ml'}, {'ingredient': 'onion', 'quantity': 1.0, 'unit': 'ea'}, {'ingredient': 'salt', 'quantity': 0, 'unit': 'ea'}]
# ================================================================================
# Find most similar words of << plum tomato >> in DB
# found! We will repace it to << tomato >> !  similarity is 0.9181
# ================================================================================
# Find most similar words of << butter >> in DB
# found! We will repace it to << butter >> !  similarity is 1
# ================================================================================
# Find most similar words of << onion >> in DB
# found! We will repace it to << onion >> !  similarity is 1
# ================================================================================
# Find most similar words of << salt >> in DB
# found! We will repace it to << salt >> !  similarity is 1
# corner case:  onion
# [{'ingredient': 'tomato', 'quantity': 473.18, 'unit': 'ml'}, {'ingredient': 'butter', 'quantity': 73.94, 'unit': 'ml'}, {'ingredient': 'onion', 'quantity': 100.0, 'unit': 'ea'}, {'ingredient': 'salt', 'quantity': 0, 'unit': 'ea'}]
# tuna--pea--and-brown-rice-casserole-97966
# 5
# https://www.food.com/recipe/tuna-pea-and-brown-rice-casserole-97966?units=metric&scale=5
# [{'ingredient': 'brown rice', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'campbell mushroom soup', 'quantity': 304.75, 'unit': 'g'}, {'ingredient': 'tuna', 'quantity': 170.09, 'unit': 'g'}, {'ingredient': 'peas', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'pepper', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'breadcrumbs', 'quantity': 29.58, 'unit': 'ml'}, {'ingredient': 'cheddar cheese', 'quantity': 118.29, 'unit': 'ml'}]
# ================================================================================
# Find most similar words of << brown rice >> in DB
# found! We will repace it to << brown rice >> !  similarity is 1
# ================================================================================
# Find most similar words of << campbell mushroom soup >> in DB
# found! We will repace it to << mushrooms >> !  similarity is 0.8179
# ================================================================================
# Find most similar words of << tuna >> in DB
# found! We will repace it to << tuna >> !  similarity is 1
# ================================================================================
# Find most similar words of << peas >> in DB
# found! We will repace it to << peas >> !  similarity is 1
# ================================================================================
# Find most similar words of << pepper >> in DB
# found! We will repace it to << pepper >> !  similarity is 1
# ================================================================================
# Find most similar words of << breadcrumbs >> in DB
# found! We will repace it to << panko >> !  similarity is 0.6768
# but it looks not so similar :( we will mark as none from the recipe
# ================================================================================
# Find most similar words of << cheddar cheese >> in DB
# found! We will repace it to << cheddar cheese >> !  similarity is 1
# [{'ingredient': 'brown rice', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'mushrooms', 'quantity': 304.75, 'unit': 'g'}, {'ingredient': 'tuna', 'quantity': 170.09, 'unit': 'g'}, {'ingredient': 'peas', 'quantity': 236.59, 'unit': 'ml'}, {'ingredient': 'pepper', 'quantity': 0, 'unit': 'ea'}, {'ingredient': 'cheddar cheese', 'quantity': 118.29, 'unit': 'ml'}]

# %% [markdown]
# #6. export test result to csv

# %%
emission_series = pd.Series(emissions)/1000
frame = { 'Id': recipe_ids, 'Predicted': emission_series}
result = pd.DataFrame(frame)
#Printing elements of Dataframe
print(result)
result.to_csv('./result/result19.csv', index=False)  # threshold 0.2
# Out:
#         Id  Predicted
# 0   484624  14.005364
# 1   399771   3.623580
# 2   455721   3.915702
# 3   454994   0.798218
# 4   361646   1.005724
# 5    26219   0.075363
# 6    53252   3.467726
# 7   186382   1.460709
# 8   130632  10.746397
# 9   257067   0.897406
# 10   28149   1.908730
# 11  112082   1.321915
# 12  154088   4.055881
# 13  313094   0.917267
# 14  382812   2.337794
# 15   64322   1.282719
# 16   10328  15.866479
# 17  274736   0.468515
# 18  424780   0.713120
# 19  390247   2.373718
# 20  513985   3.056657
# 21  206463   1.930524
# 22   38596   1.802233
# 23   23706   5.161284
# 24  292213   0.671040
# 25  370726   8.265399
# 26  240843   8.686743
# 27   49249   0.810369
# 28  110813   2.113857
# 29   66190   5.538238
# 30  252674  15.056439
# 31  512810   0.149529
# 32  113725   2.964763
# 33   41874   7.718285
# 34   61210   0.589061
# 35   41725   5.661189
# 36  177958   1.904362
# 37   53907   0.104849
# 38  137627   2.091881
# 39  485002   0.908696
# 40   19441   1.271882
# 41  169079   0.857944
# 42  150554   0.916752
# 43   37000   2.074479
# 44   91195   1.493405
# 45   76402   1.357623
# 46  210236   0.281911
# 47  229351   0.000000
# 48  273976   1.557497
# 49   97966   3.747173
